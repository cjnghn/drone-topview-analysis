# %%
# %pip install --quiet moviepy pandas numpy shapely geopy plotly tqdm rtree matplotlib
# Out:
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import json
from tqdm import tqdm
import matplotlib.pyplot as plt
from dataclasses import dataclass
from typing import List, Dict, Optional, Tuple, NamedTuple

# %%
data_dir = Path("./data")

flight_log_path = data_dir / "flight_log.csv"
tracking_paths = [data_dir / "tracking1.json", data_dir / "tracking2.json"]

# %%
# 기본 데이터 모델
class Point(NamedTuple):
    x: float
    y: float


class GeoPoint(NamedTuple):
    latitude: float
    longitude: float


@dataclass
class DroneState:
    position: GeoPoint
    altitude: float
    heading: float
    timestamp: float

# %%
def find_video_segments(flight_log: pd.DataFrame) -> List[pd.DataFrame]:
    """비디오 구간을 찾아서 반환"""
    segments = []
    current_segment = []

    for _, row in flight_log.iterrows():
        if row["isVideo"] == 1:
            current_segment.append(row)
        else:
            if current_segment:
                segments.append(pd.DataFrame(current_segment))
                current_segment = []

    if current_segment:
        segments.append(pd.DataFrame(current_segment))

    return segments

# %%
# 실행
flight_log = pd.read_csv(flight_log_path)
segments = find_video_segments(flight_log)

print(f"총 {len(segments)}개의 비디오 구간을 찾았습니다.\n")
for i, segment in enumerate(segments, 1):
    start_time = segment["time(millisecond)"].iloc[0] / 1000
    end_time = segment["time(millisecond)"].iloc[-1] / 1000
    duration = end_time - start_time

    print(f"구간 {i}:")
    print(f"  시작 시간: {start_time:.2f}초")
    print(f"  종료 시간: {end_time:.2f}초")
    print(f"  지속 시간: {duration:.2f}초")
    print(f"  데이터 포인트 수: {len(segment)}")
    print(
        f"  시작 위치: ({segment['latitude'].iloc[0]:.6f}, {segment['longitude'].iloc[0]:.6f})"
    )
    print(
        f"  종료 위치: ({segment['latitude'].iloc[-1]:.6f}, {segment['longitude'].iloc[-1]:.6f})"
    )
    print(f"  로깅 간격: {(duration/len(segment)):.3f}초")
    print()
# Out:
# 총 2개의 비디오 구간을 찾았습니다.
#
# 구간 1:
#   시작 시간: 591.60초
#   종료 시간: 899.20초
#   지속 시간: 307.60초
#   데이터 포인트 수: 1539
#   시작 위치: (37.451060, 126.656443)
#   종료 위치: (37.451059, 126.656434)
#   로깅 간격: 0.200초
#
# 구간 2:
#   시작 시간: 967.40초
#   종료 시간: 1217.60초
#   지속 시간: 250.20초
#   데이터 포인트 수: 1251
#   시작 위치: (37.449199, 126.656013)
#   종료 위치: (37.449199, 126.656008)
#   로깅 간격: 0.200초

# %%
def create_frame_drone_mapping(
    segment_df: pd.DataFrame, tracking_data: dict
) -> List[Dict]:
    """프레임별 드론 상태 매핑"""
    fps = tracking_data["video"]["fps"]
    segment_start_time = segment_df["time(millisecond)"].iloc[0] / 1000

    frames = []
    for frame_data in tqdm(tracking_data["tracking_results"], desc="프레임 매핑"):
        frame_idx = frame_data["i"]
        frame_time = segment_start_time + (frame_idx / fps)

        # 가장 가까운 flight log 찾기
        closest_log = segment_df.iloc[
            (segment_df["time(millisecond)"] / 1000 - frame_time).abs().argmin()
        ]

        frame_info = {
            "frame_index": frame_idx,
            "timestamp": frame_time,
            "drone_state": {
                "latitude": closest_log["latitude"],
                "longitude": closest_log["longitude"],
                "altitude": closest_log["ascent(feet)"] * 0.3048,  # feet to meters
                "heading": closest_log["compass_heading(degrees)"],
            },
            "objects": frame_data["res"],
        }
        frames.append(frame_info)

    return frames

# %%
# 첫 번째 세그먼트에 대해 실행
with open(tracking_paths[0], "r") as f:
    tracking_data = json.load(f)

frames = create_frame_drone_mapping(segments[0], tracking_data)

# 첫 다섯개 프레임 정보 출력
for i in range(5):
    print(f"첫 {i} 프레임 정보:")
    print(f"프레임 인덱스: {frames[i]['frame_index']}")
    print(f"타임스탬프: {frames[i]['timestamp']:.2f}초")
    print(f"드론 상태:")
    print(f"  위도: {frames[i]['drone_state']['latitude']}")
    print(f"  경도: {frames[i]['drone_state']['longitude']}")
    print(f"  고도: {frames[i]['drone_state']['altitude']:.1f}m")
    print(f"  방향: {frames[i]['drone_state']['heading']}°")
    print(f"객체 수: {len(frames[i]['objects'])}")
# Out:
# 프레임 매핑: 100%|██████████| 9223/9223 [00:00<00:00, 10903.05it/s]
# 첫 0 프레임 정보:
# 프레임 인덱스: 0
# 타임스탬프: 591.60초
# 드론 상태:
#   위도: 37.4510599991108
#   경도: 126.656443306919
#   고도: 40.0m
#   방향: 289.1°
# 객체 수: 68
# 첫 1 프레임 정보:
# 프레임 인덱스: 1
# 타임스탬프: 591.63초
# 드론 상태:
#   위도: 37.4510599991108
#   경도: 126.656443306919
#   고도: 40.0m
#   방향: 289.1°
# 객체 수: 68
# 첫 2 프레임 정보:
# 프레임 인덱스: 2
# 타임스탬프: 591.67초
# 드론 상태:
#   위도: 37.4510599991108
#   경도: 126.656443306919
#   고도: 40.0m
#   방향: 289.1°
# 객체 수: 68
# 첫 3 프레임 정보:
# 프레임 인덱스: 3
# 타임스탬프: 591.70초
# 드론 상태:
#   위도: 37.4510601350421
#   경도: 126.656443250977
#   고도: 40.0m
#   방향: 289.1°
# 객체 수: 69
# 첫 4 프레임 정보:
# 프레임 인덱스: 4
# 타임스탬프: 591.73초
# 드론 상태:
#   위도: 37.4510601350421
#   경도: 126.656443250977
#   고도: 40.0m
#   방향: 289.1°
# 객체 수: 69

# %%
from dataclasses import dataclass
from typing import List, Dict, Tuple
from rtree import index
from concurrent.futures import ThreadPoolExecutor
from tqdm import tqdm


@dataclass
class Segment:
    """선분 정보를 담는 데이터 클래스"""

    track_id: int
    p1: Tuple[float, float]  # (x1, y1)
    p2: Tuple[float, float]  # (x2, y2)
    t1: float  # timestamp1
    t2: float  # timestamp2
    frame1: int
    frame2: int


def get_trajectory_segments(
    frames: List[Dict], window_start: int, window_size: int
) -> List[Segment]:
    """프레임 윈도우에서 모든 궤적 선분 추출"""
    segments = []
    window_frames = frames[window_start : window_start + window_size]

    object_positions = {}
    for frame in window_frames:
        for obj in frame["objects"]:
            track_id = obj["tid"]
            if track_id not in object_positions:
                object_positions[track_id] = []

            # 중심점 계산
            x = (obj["bbox"][0] + obj["bbox"][2]) / 2
            y = (obj["bbox"][1] + obj["bbox"][3]) / 2

            object_positions[track_id].append(
                {
                    "point": (x, y),
                    "frame": frame["frame_index"],
                    "time": frame["timestamp"],
                }
            )

    # 선분 생성
    for track_id, positions in object_positions.items():
        if len(positions) < 2:
            continue
        for i in range(len(positions) - 1):
            segments.append(
                Segment(
                    track_id=track_id,
                    p1=positions[i]["point"],
                    p2=positions[i + 1]["point"],
                    t1=positions[i]["time"],
                    t2=positions[i + 1]["time"],
                    frame1=positions[i]["frame"],
                    frame2=positions[i + 1]["frame"],
                )
            )

    return segments


def line_segments_intersect(seg1: Segment, seg2: Segment) -> Tuple[float, float]:
    """두 선분의 교차점 계산"""
    x1, y1 = seg1.p1
    x2, y2 = seg1.p2
    x3, y3 = seg2.p1
    x4, y4 = seg2.p2

    denominator = (x1 - x2) * (y3 - y4) - (y1 - y2) * (x3 - x4)
    if denominator == 0:
        return None

    t = ((x1 - x3) * (y3 - y4) - (y1 - y3) * (x3 - x4)) / denominator
    u = -((x1 - x2) * (y1 - y3) - (y1 - y2) * (x1 - x3)) / denominator

    if 0 <= t <= 1 and 0 <= u <= 1:
        x = x1 + t * (x2 - x1)
        y = y1 + t * (y2 - y1)
        return (x, y)

    return None


def process_window(args) -> List[Dict]:
    """하나의 윈도우 처리"""
    frames, window_start, window_size = args
    segments = get_trajectory_segments(frames, window_start, window_size)

    # R-Tree 인덱스 생성
    idx = index.Index()
    for i, seg in enumerate(segments):
        # 선분의 bounding box 계산
        bbox = (
            min(seg.p1[0], seg.p2[0]),
            min(seg.p1[1], seg.p2[1]),
            max(seg.p1[0], seg.p2[0]),
            max(seg.p1[1], seg.p2[1]),
        )
        idx.insert(i, bbox)  # 각 선분을 개별 삽입

    # 교차점 계산
    intersections = []
    processed_pairs = set()

    for i, seg1 in enumerate(segments):
        bbox = (
            min(seg1.p1[0], seg1.p2[0]),
            min(seg1.p1[1], seg1.p2[1]),
            max(seg1.p1[0], seg1.p2[0]),
            max(seg1.p1[1], seg1.p2[1]),
        )
        for j in idx.intersection(bbox):
            if i >= j:  # 중복 방지
                continue
            seg2 = segments[j]
            pair = tuple(sorted([seg1.track_id, seg2.track_id]))
            if pair in processed_pairs:
                continue
            processed_pairs.add(pair)
            if seg1.track_id == seg2.track_id:
                continue

            intersection = line_segments_intersect(seg1, seg2)
            if intersection:
                time_diff = abs(seg1.t1 - seg2.t1)
                intersections.append(
                    {
                        "frame_index": min(seg1.frame1, seg2.frame1),
                        "timestamp": min(seg1.t1, seg2.t1),
                        "track_id1": seg1.track_id,
                        "track_id2": seg2.track_id,
                        "intersection_point": intersection,
                        "time_difference": time_diff,
                    }
                )

    return intersections


def analyze_trajectories_in_frame_window(
    frames: List[Dict], window_size: int = 30 * 10
) -> List[Dict]:
    """멀티스레딩을 사용한 궤적 분석"""
    tasks = [
        (frames, i, window_size)
        for i in range(0, len(frames) - window_size, window_size)
    ]

    # 멀티스레딩 실행
    all_intersections = []
    with ThreadPoolExecutor() as executor:
        for result in tqdm(
            executor.map(process_window, tasks), total=len(tasks), desc="궤적 분석"
        ):
            all_intersections.extend(result)

    return all_intersections

# %%
# 픽셀 속도 계싼해봅시다.
import math


def calculate_pixel_speed(frames):
    """
    각 객체의 픽셀 속도를 계산합니다.
    Args:
        frames (List[Dict]): 프레임 정보
    Returns:
        Dict: 객체별 픽셀 속도 정보
    """
    object_speeds = {}

    for frame in frames:
        for obj in frame["objects"]:
            track_id = obj["tid"]
            # 중심점 계산
            x = (obj["bbox"][0] + obj["bbox"][2]) / 2
            y = (obj["bbox"][1] + obj["bbox"][3]) / 2
            timestamp = frame["timestamp"]

            if track_id not in object_speeds:
                # 객체 초기화
                object_speeds[track_id] = {"positions": [], "speeds": []}

            # 현재 위치 저장
            object_speeds[track_id]["positions"].append(
                {"x": x, "y": y, "timestamp": timestamp}
            )

    # 속도 계산
    for track_id, data in object_speeds.items():
        positions = data["positions"]
        for i in range(1, len(positions)):
            prev = positions[i - 1]
            curr = positions[i]
            # 픽셀 거리 계산
            distance = math.sqrt(
                (curr["x"] - prev["x"]) ** 2 + (curr["y"] - prev["y"]) ** 2
            )
            # 시간 차이 계산
            time_diff = curr["timestamp"] - prev["timestamp"]
            # 속도 계산 (pixels/second)
            if time_diff > 0:
                speed = distance / time_diff
                data["speeds"].append(speed)
            else:
                data["speeds"].append(0)

    return object_speeds

# %%
# 예제 실행
object_pixel_speeds = calculate_pixel_speed(frames)

# 객체별 평균 픽셀 속도 출력
for track_id, data in object_pixel_speeds.items():
    average_speed = sum(data["speeds"]) / len(data["speeds"]) if data["speeds"] else 0
    print(f"객체 {track_id}의 평균 픽셀 속도: {average_speed:.2f} pixels/second")
# Out:
# 객체 1의 평균 픽셀 속도: 9.22 pixels/second
# 객체 2의 평균 픽셀 속도: 6.68 pixels/second
# 객체 3의 평균 픽셀 속도: 12.56 pixels/second
# 객체 4의 평균 픽셀 속도: 6.33 pixels/second
# 객체 5의 평균 픽셀 속도: 4.15 pixels/second
# 객체 6의 평균 픽셀 속도: 58.89 pixels/second
# 객체 7의 평균 픽셀 속도: 287.81 pixels/second
# 객체 8의 평균 픽셀 속도: 4.83 pixels/second
# 객체 9의 평균 픽셀 속도: 11.07 pixels/second
# 객체 10의 평균 픽셀 속도: 75.28 pixels/second
# 객체 11의 평균 픽셀 속도: 70.69 pixels/second
# 객체 12의 평균 픽셀 속도: 61.78 pixels/second
# 객체 13의 평균 픽셀 속도: 65.59 pixels/second
# 객체 14의 평균 픽셀 속도: 52.24 pixels/second
# 객체 15의 평균 픽셀 속도: 92.79 pixels/second
# 객체 16의 평균 픽셀 속도: 38.85 pixels/second
# 객체 17의 평균 픽셀 속도: 8.56 pixels/second
# 객체 18의 평균 픽셀 속도: 28.03 pixels/second
# 객체 19의 평균 픽셀 속도: 72.13 pixels/second
# 객체 20의 평균 픽셀 속도: 67.01 pixels/second
# 객체 21의 평균 픽셀 속도: 27.00 pixels/second
# 객체 22의 평균 픽셀 속도: 73.56 pixels/second
# 객체 23의 평균 픽셀 속도: 69.33 pixels/second
# 객체 24의 평균 픽셀 속도: 95.71 pixels/second
# 객체 25의 평균 픽셀 속도: 75.40 pixels/second
# 객체 26의 평균 픽셀 속도: 72.03 pixels/second
# 객체 27의 평균 픽셀 속도: 64.70 pixels/second
# 객체 28의 평균 픽셀 속도: 28.77 pixels/second
# 객체 29의 평균 픽셀 속도: 31.88 pixels/second
# 객체 30의 평균 픽셀 속도: 40.05 pixels/second
# 객체 31의 평균 픽셀 속도: 79.42 pixels/second
# 객체 32의 평균 픽셀 속도: 76.31 pixels/second
# 객체 33의 평균 픽셀 속도: 65.76 pixels/second
# 객체 34의 평균 픽셀 속도: 28.33 pixels/second
# 객체 35의 평균 픽셀 속도: 20.47 pixels/second
# 객체 36의 평균 픽셀 속도: 26.58 pixels/second
# 객체 37의 평균 픽셀 속도: 69.00 pixels/second
# 객체 38의 평균 픽셀 속도: 78.11 pixels/second
# 객체 39의 평균 픽셀 속도: 94.60 pixels/second
# 객체 40의 평균 픽셀 속도: 64.52 pixels/second
# 객체 41의 평균 픽셀 속도: 89.45 pixels/second
# 객체 42의 평균 픽셀 속도: 77.81 pixels/second
# 객체 43의 평균 픽셀 속도: 10.49 pixels/second
# 객체 44의 평균 픽셀 속도: 81.24 pixels/second
# 객체 45의 평균 픽셀 속도: 32.61 pixels/second
# 객체 46의 평균 픽셀 속도: 70.25 pixels/second
# 객체 47의 평균 픽셀 속도: 27.17 pixels/second
# 객체 48의 평균 픽셀 속도: 81.10 pixels/second
# 객체 49의 평균 픽셀 속도: 97.29 pixels/second
# 객체 50의 평균 픽셀 속도: 67.10 pixels/second
# 객체 51의 평균 픽셀 속도: 43.28 pixels/second
# 객체 52의 평균 픽셀 속도: 29.05 pixels/second
# 객체 53의 평균 픽셀 속도: 66.93 pixels/second
# 객체 54의 평균 픽셀 속도: 38.81 pixels/second
# 객체 55의 평균 픽셀 속도: 86.29 pixels/second
# 객체 56의 평균 픽셀 속도: 100.46 pixels/second
# 객체 57의 평균 픽셀 속도: 79.12 pixels/second
# 객체 58의 평균 픽셀 속도: 13.00 pixels/second
# 객체 59의 평균 픽셀 속도: 37.19 pixels/second
# 객체 60의 평균 픽셀 속도: 33.46 pixels/second
# 객체 61의 평균 픽셀 속도: 86.00 pixels/second
# 객체 62의 평균 픽셀 속도: 68.62 pixels/second
# 객체 63의 평균 픽셀 속도: 13.06 pixels/second
# 객체 64의 평균 픽셀 속도: 81.05 pixels/second
# 객체 65의 평균 픽셀 속도: 82.02 pixels/second
# 객체 66의 평균 픽셀 속도: 75.93 pixels/second
# 객체 67의 평균 픽셀 속도: 152.22 pixels/second
# 객체 68의 평균 픽셀 속도: 61.28 pixels/second
# 객체 70의 평균 픽셀 속도: 30.90 pixels/second
# 객체 72의 평균 픽셀 속도: 83.55 pixels/second
# 객체 75의 평균 픽셀 속도: 71.27 pixels/second
# 객체 76의 평균 픽셀 속도: 42.28 pixels/second
# 객체 77의 평균 픽셀 속도: 66.38 pixels/second
# 객체 79의 평균 픽셀 속도: 55.16 pixels/second
# 객체 83의 평균 픽셀 속도: 15.55 pixels/second
# 객체 84의 평균 픽셀 속도: 18.78 pixels/second
# 객체 89의 평균 픽셀 속도: 72.61 pixels/second
# 객체 91의 평균 픽셀 속도: 57.29 pixels/second
# 객체 92의 평균 픽셀 속도: 12.47 pixels/second
# 객체 93의 평균 픽셀 속도: 14.38 pixels/second
# 객체 94의 평균 픽셀 속도: 7.01 pixels/second
# 객체 95의 평균 픽셀 속도: 64.91 pixels/second
# 객체 96의 평균 픽셀 속도: 94.36 pixels/second
# 객체 103의 평균 픽셀 속도: 71.25 pixels/second
# 객체 104의 평균 픽셀 속도: 0.00 pixels/second
# 객체 105의 평균 픽셀 속도: 60.22 pixels/second
# 객체 107의 평균 픽셀 속도: 5.54 pixels/second
# 객체 108의 평균 픽셀 속도: 270.32 pixels/second
# 객체 109의 평균 픽셀 속도: 44.14 pixels/second
# 객체 110의 평균 픽셀 속도: 509.60 pixels/second
# 객체 111의 평균 픽셀 속도: 68.25 pixels/second
# 객체 112의 평균 픽셀 속도: 79.30 pixels/second
# 객체 113의 평균 픽셀 속도: 18.95 pixels/second
# 객체 114의 평균 픽셀 속도: 12.62 pixels/second
# 객체 116의 평균 픽셀 속도: 264.24 pixels/second
# 객체 117의 평균 픽셀 속도: 7.54 pixels/second
# 객체 118의 평균 픽셀 속도: 109.40 pixels/second
# 객체 122의 평균 픽셀 속도: 34.62 pixels/second
# 객체 125의 평균 픽셀 속도: 72.93 pixels/second
# 객체 126의 평균 픽셀 속도: 81.60 pixels/second
# 객체 127의 평균 픽셀 속도: 45.02 pixels/second
# 객체 128의 평균 픽셀 속도: 60.17 pixels/second
# 객체 130의 평균 픽셀 속도: 20.87 pixels/second
# 객체 131의 평균 픽셀 속도: 26.88 pixels/second
# 객체 133의 평균 픽셀 속도: 0.00 pixels/second
# 객체 134의 평균 픽셀 속도: 69.75 pixels/second
# 객체 136의 평균 픽셀 속도: 76.36 pixels/second
# 객체 137의 평균 픽셀 속도: 74.31 pixels/second
# 객체 138의 평균 픽셀 속도: 7.09 pixels/second
# 객체 140의 평균 픽셀 속도: 254.41 pixels/second
# 객체 141의 평균 픽셀 속도: 648.04 pixels/second
# 객체 143의 평균 픽셀 속도: 498.95 pixels/second
# 객체 146의 평균 픽셀 속도: 16.04 pixels/second
# 객체 147의 평균 픽셀 속도: 20.98 pixels/second
# 객체 148의 평균 픽셀 속도: 95.04 pixels/second
# 객체 149의 평균 픽셀 속도: 12.00 pixels/second
# 객체 151의 평균 픽셀 속도: 61.47 pixels/second
# 객체 152의 평균 픽셀 속도: 28.42 pixels/second
# 객체 155의 평균 픽셀 속도: 55.35 pixels/second
# 객체 156의 평균 픽셀 속도: 91.33 pixels/second
# 객체 157의 평균 픽셀 속도: 76.12 pixels/second
# 객체 158의 평균 픽셀 속도: 3.59 pixels/second
# 객체 164의 평균 픽셀 속도: 44.30 pixels/second
# 객체 165의 평균 픽셀 속도: 68.07 pixels/second
# 객체 166의 평균 픽셀 속도: 43.03 pixels/second
# 객체 168의 평균 픽셀 속도: 77.06 pixels/second
# 객체 169의 평균 픽셀 속도: 72.44 pixels/second
# 객체 170의 평균 픽셀 속도: 402.73 pixels/second
# 객체 171의 평균 픽셀 속도: 70.75 pixels/second
# 객체 172의 평균 픽셀 속도: 61.03 pixels/second
# 객체 174의 평균 픽셀 속도: 67.15 pixels/second
# 객체 175의 평균 픽셀 속도: 105.53 pixels/second
# 객체 179의 평균 픽셀 속도: 38.51 pixels/second
# 객체 181의 평균 픽셀 속도: 80.89 pixels/second
# 객체 182의 평균 픽셀 속도: 44.84 pixels/second
# 객체 184의 평균 픽셀 속도: 7.32 pixels/second
# 객체 185의 평균 픽셀 속도: 94.62 pixels/second
# 객체 187의 평균 픽셀 속도: 87.10 pixels/second
# 객체 188의 평균 픽셀 속도: 79.26 pixels/second
# 객체 189의 평균 픽셀 속도: 12.57 pixels/second
# 객체 190의 평균 픽셀 속도: 35.85 pixels/second
# 객체 191의 평균 픽셀 속도: 67.63 pixels/second
# 객체 192의 평균 픽셀 속도: 43.71 pixels/second
# 객체 193의 평균 픽셀 속도: 72.50 pixels/second
# 객체 194의 평균 픽셀 속도: 72.14 pixels/second
# 객체 197의 평균 픽셀 속도: 89.33 pixels/second
# 객체 198의 평균 픽셀 속도: 0.00 pixels/second
# 객체 201의 평균 픽셀 속도: 96.14 pixels/second
# 객체 202의 평균 픽셀 속도: 73.33 pixels/second
# 객체 204의 평균 픽셀 속도: 49.67 pixels/second
# 객체 205의 평균 픽셀 속도: 50.41 pixels/second
# 객체 207의 평균 픽셀 속도: 57.23 pixels/second
# 객체 208의 평균 픽셀 속도: 0.00 pixels/second
# 객체 209의 평균 픽셀 속도: 0.00 pixels/second
# 객체 210의 평균 픽셀 속도: 89.37 pixels/second
# 객체 213의 평균 픽셀 속도: 81.82 pixels/second
# 객체 214의 평균 픽셀 속도: 65.84 pixels/second
# 객체 215의 평균 픽셀 속도: 58.49 pixels/second
# 객체 216의 평균 픽셀 속도: 135.49 pixels/second
# 객체 218의 평균 픽셀 속도: 69.93 pixels/second
# 객체 219의 평균 픽셀 속도: 28.46 pixels/second
# 객체 220의 평균 픽셀 속도: 41.14 pixels/second
# 객체 222의 평균 픽셀 속도: 74.33 pixels/second
# 객체 223의 평균 픽셀 속도: 85.03 pixels/second
# 객체 225의 평균 픽셀 속도: 250.94 pixels/second
# 객체 226의 평균 픽셀 속도: 78.64 pixels/second
# 객체 227의 평균 픽셀 속도: 84.13 pixels/second
# 객체 228의 평균 픽셀 속도: 74.50 pixels/second
# 객체 230의 평균 픽셀 속도: 115.64 pixels/second
# 객체 232의 평균 픽셀 속도: 637.83 pixels/second
# 객체 234의 평균 픽셀 속도: 63.97 pixels/second
# 객체 237의 평균 픽셀 속도: 263.09 pixels/second
# 객체 238의 평균 픽셀 속도: 81.54 pixels/second
# 객체 241의 평균 픽셀 속도: 537.92 pixels/second
# 객체 242의 평균 픽셀 속도: 68.66 pixels/second
# 객체 244의 평균 픽셀 속도: 26.81 pixels/second
# 객체 245의 평균 픽셀 속도: 38.36 pixels/second
# 객체 246의 평균 픽셀 속도: 64.25 pixels/second
# 객체 247의 평균 픽셀 속도: 35.10 pixels/second
# 객체 249의 평균 픽셀 속도: 76.37 pixels/second
# 객체 254의 평균 픽셀 속도: 46.80 pixels/second
# 객체 255의 평균 픽셀 속도: 57.53 pixels/second
# 객체 259의 평균 픽셀 속도: 46.29 pixels/second
# 객체 260의 평균 픽셀 속도: 63.70 pixels/second
# 객체 261의 평균 픽셀 속도: 94.44 pixels/second
# 객체 263의 평균 픽셀 속도: 65.68 pixels/second
# 객체 266의 평균 픽셀 속도: 80.77 pixels/second
# 객체 268의 평균 픽셀 속도: 85.11 pixels/second
# 객체 269의 평균 픽셀 속도: 69.59 pixels/second
# 객체 272의 평균 픽셀 속도: 61.11 pixels/second
# 객체 273의 평균 픽셀 속도: 85.78 pixels/second
# 객체 274의 평균 픽셀 속도: 125.62 pixels/second
# 객체 276의 평균 픽셀 속도: 81.36 pixels/second
# 객체 277의 평균 픽셀 속도: 123.79 pixels/second
# 객체 279의 평균 픽셀 속도: 211.49 pixels/second
# 객체 283의 평균 픽셀 속도: 70.62 pixels/second
# 객체 285의 평균 픽셀 속도: 54.33 pixels/second
# 객체 286의 평균 픽셀 속도: 78.75 pixels/second
# 객체 287의 평균 픽셀 속도: 60.83 pixels/second
# 객체 288의 평균 픽셀 속도: 57.62 pixels/second
# 객체 289의 평균 픽셀 속도: 65.78 pixels/second
# 객체 290의 평균 픽셀 속도: 38.32 pixels/second
# 객체 291의 평균 픽셀 속도: 47.81 pixels/second
# 객체 293의 평균 픽셀 속도: 39.37 pixels/second
# 객체 294의 평균 픽셀 속도: 72.67 pixels/second
# 객체 295의 평균 픽셀 속도: 86.02 pixels/second
# 객체 297의 평균 픽셀 속도: 72.35 pixels/second
# 객체 300의 평균 픽셀 속도: 45.47 pixels/second
# 객체 301의 평균 픽셀 속도: 74.07 pixels/second
# 객체 302의 평균 픽셀 속도: 75.53 pixels/second
# 객체 303의 평균 픽셀 속도: 91.85 pixels/second
# 객체 304의 평균 픽셀 속도: 56.54 pixels/second
# 객체 306의 평균 픽셀 속도: 76.11 pixels/second
# 객체 308의 평균 픽셀 속도: 17.19 pixels/second
# 객체 309의 평균 픽셀 속도: 69.40 pixels/second
# 객체 310의 평균 픽셀 속도: 56.85 pixels/second
# 객체 311의 평균 픽셀 속도: 70.51 pixels/second
# 객체 312의 평균 픽셀 속도: 60.39 pixels/second
# 객체 313의 평균 픽셀 속도: 77.49 pixels/second
# 객체 314의 평균 픽셀 속도: 76.61 pixels/second
# 객체 315의 평균 픽셀 속도: 285.77 pixels/second
# 객체 316의 평균 픽셀 속도: 73.21 pixels/second
# 객체 318의 평균 픽셀 속도: 57.71 pixels/second
# 객체 319의 평균 픽셀 속도: 52.32 pixels/second
# 객체 325의 평균 픽셀 속도: 24.61 pixels/second
# 객체 329의 평균 픽셀 속도: 116.95 pixels/second
# 객체 331의 평균 픽셀 속도: 83.22 pixels/second
# 객체 333의 평균 픽셀 속도: 90.36 pixels/second
# 객체 334의 평균 픽셀 속도: 26.32 pixels/second
# 객체 335의 평균 픽셀 속도: 46.83 pixels/second
# 객체 336의 평균 픽셀 속도: 37.28 pixels/second
# 객체 337의 평균 픽셀 속도: 65.31 pixels/second
# 객체 339의 평균 픽셀 속도: 6.86 pixels/second
# 객체 345의 평균 픽셀 속도: 50.43 pixels/second
# 객체 348의 평균 픽셀 속도: 153.20 pixels/second
# 객체 351의 평균 픽셀 속도: 102.23 pixels/second
# 객체 352의 평균 픽셀 속도: 39.57 pixels/second
# 객체 353의 평균 픽셀 속도: 275.19 pixels/second
# 객체 354의 평균 픽셀 속도: 31.20 pixels/second
# 객체 355의 평균 픽셀 속도: 16.04 pixels/second
# 객체 357의 평균 픽셀 속도: 14.57 pixels/second
# 객체 358의 평균 픽셀 속도: 58.79 pixels/second
# 객체 359의 평균 픽셀 속도: 77.16 pixels/second
# 객체 360의 평균 픽셀 속도: 47.23 pixels/second
# 객체 363의 평균 픽셀 속도: 66.95 pixels/second
# 객체 364의 평균 픽셀 속도: 81.12 pixels/second
# 객체 365의 평균 픽셀 속도: 111.03 pixels/second
# 객체 366의 평균 픽셀 속도: 77.72 pixels/second
# 객체 369의 평균 픽셀 속도: 18.49 pixels/second
# 객체 370의 평균 픽셀 속도: 76.80 pixels/second
# 객체 371의 평균 픽셀 속도: 72.34 pixels/second
# 객체 372의 평균 픽셀 속도: 41.37 pixels/second
# 객체 373의 평균 픽셀 속도: 72.13 pixels/second
# 객체 376의 평균 픽셀 속도: 115.15 pixels/second
# 객체 377의 평균 픽셀 속도: 61.01 pixels/second
# 객체 378의 평균 픽셀 속도: 36.54 pixels/second
# 객체 379의 평균 픽셀 속도: 471.54 pixels/second
# 객체 380의 평균 픽셀 속도: 58.87 pixels/second
# 객체 382의 평균 픽셀 속도: 27.36 pixels/second
# 객체 383의 평균 픽셀 속도: 87.19 pixels/second
# 객체 387의 평균 픽셀 속도: 27.57 pixels/second
# 객체 389의 평균 픽셀 속도: 88.11 pixels/second
# 객체 390의 평균 픽셀 속도: 47.10 pixels/second
# 객체 391의 평균 픽셀 속도: 67.99 pixels/second
# 객체 392의 평균 픽셀 속도: 91.52 pixels/second
# 객체 393의 평균 픽셀 속도: 385.48 pixels/second
# 객체 394의 평균 픽셀 속도: 141.26 pixels/second
# 객체 397의 평균 픽셀 속도: 68.66 pixels/second
# 객체 398의 평균 픽셀 속도: 107.29 pixels/second
# 객체 399의 평균 픽셀 속도: 13.78 pixels/second
# 객체 401의 평균 픽셀 속도: 10.66 pixels/second
# 객체 402의 평균 픽셀 속도: 12.46 pixels/second
# 객체 403의 평균 픽셀 속도: 67.93 pixels/second
# 객체 405의 평균 픽셀 속도: 0.00 pixels/second
# 객체 407의 평균 픽셀 속도: 36.73 pixels/second
# 객체 411의 평균 픽셀 속도: 61.83 pixels/second
# 객체 412의 평균 픽셀 속도: 236.39 pixels/second
# 객체 414의 평균 픽셀 속도: 70.77 pixels/second
# 객체 415의 평균 픽셀 속도: 106.35 pixels/second
# 객체 418의 평균 픽셀 속도: 79.37 pixels/second
# 객체 420의 평균 픽셀 속도: 5.17 pixels/second
# 객체 422의 평균 픽셀 속도: 116.84 pixels/second
# 객체 423의 평균 픽셀 속도: 234.72 pixels/second
# 객체 424의 평균 픽셀 속도: 32.83 pixels/second
# 객체 425의 평균 픽셀 속도: 70.67 pixels/second
# 객체 426의 평균 픽셀 속도: 62.40 pixels/second
# 객체 427의 평균 픽셀 속도: 55.91 pixels/second
# 객체 429의 평균 픽셀 속도: 96.49 pixels/second
# 객체 430의 평균 픽셀 속도: 55.43 pixels/second
# 객체 431의 평균 픽셀 속도: 78.10 pixels/second
# 객체 432의 평균 픽셀 속도: 9.68 pixels/second
# 객체 433의 평균 픽셀 속도: 84.08 pixels/second
# 객체 436의 평균 픽셀 속도: 106.25 pixels/second
# 객체 442의 평균 픽셀 속도: 69.69 pixels/second
# 객체 443의 평균 픽셀 속도: 84.60 pixels/second
# 객체 444의 평균 픽셀 속도: 79.05 pixels/second
# 객체 445의 평균 픽셀 속도: 71.00 pixels/second
# 객체 446의 평균 픽셀 속도: 90.50 pixels/second
# 객체 447의 평균 픽셀 속도: 78.87 pixels/second
# 객체 448의 평균 픽셀 속도: 79.38 pixels/second
# 객체 449의 평균 픽셀 속도: 73.33 pixels/second
# 객체 450의 평균 픽셀 속도: 65.95 pixels/second
# 객체 451의 평균 픽셀 속도: 45.12 pixels/second
# 객체 455의 평균 픽셀 속도: 24.41 pixels/second
# 객체 456의 평균 픽셀 속도: 111.32 pixels/second
# 객체 460의 평균 픽셀 속도: 0.00 pixels/second
# 객체 461의 평균 픽셀 속도: 67.31 pixels/second
# 객체 463의 평균 픽셀 속도: 153.96 pixels/second
# 객체 467의 평균 픽셀 속도: 144.45 pixels/second
# 객체 468의 평균 픽셀 속도: 70.66 pixels/second
# 객체 470의 평균 픽셀 속도: 25.23 pixels/second
# 객체 473의 평균 픽셀 속도: 115.48 pixels/second
# 객체 474의 평균 픽셀 속도: 274.97 pixels/second
# 객체 475의 평균 픽셀 속도: 91.95 pixels/second
# 객체 478의 평균 픽셀 속도: 71.07 pixels/second
# 객체 481의 평균 픽셀 속도: 65.06 pixels/second
# 객체 482의 평균 픽셀 속도: 70.04 pixels/second
# 객체 483의 평균 픽셀 속도: 73.06 pixels/second
# 객체 485의 평균 픽셀 속도: 71.10 pixels/second
# 객체 486의 평균 픽셀 속도: 74.56 pixels/second
# 객체 487의 평균 픽셀 속도: 1.70 pixels/second
# 객체 488의 평균 픽셀 속도: 71.67 pixels/second
# 객체 489의 평균 픽셀 속도: 74.08 pixels/second
# 객체 490의 평균 픽셀 속도: 43.76 pixels/second
# 객체 491의 평균 픽셀 속도: 77.20 pixels/second
# 객체 493의 평균 픽셀 속도: 77.93 pixels/second
# 객체 494의 평균 픽셀 속도: 88.68 pixels/second
# 객체 495의 평균 픽셀 속도: 83.83 pixels/second
# 객체 496의 평균 픽셀 속도: 56.66 pixels/second
# 객체 498의 평균 픽셀 속도: 101.23 pixels/second
# 객체 499의 평균 픽셀 속도: 73.46 pixels/second
# 객체 501의 평균 픽셀 속도: 42.33 pixels/second
# 객체 502의 평균 픽셀 속도: 72.91 pixels/second
# 객체 506의 평균 픽셀 속도: 66.25 pixels/second
# 객체 507의 평균 픽셀 속도: 72.36 pixels/second
# 객체 508의 평균 픽셀 속도: 81.19 pixels/second
# 객체 509의 평균 픽셀 속도: 80.78 pixels/second
# 객체 510의 평균 픽셀 속도: 44.11 pixels/second
# 객체 511의 평균 픽셀 속도: 69.70 pixels/second
# 객체 512의 평균 픽셀 속도: 92.84 pixels/second
# 객체 513의 평균 픽셀 속도: 157.68 pixels/second
# 객체 515의 평균 픽셀 속도: 91.80 pixels/second
# 객체 517의 평균 픽셀 속도: 73.20 pixels/second
# 객체 521의 평균 픽셀 속도: 71.49 pixels/second
# 객체 522의 평균 픽셀 속도: 77.22 pixels/second
# 객체 523의 평균 픽셀 속도: 91.23 pixels/second
# 객체 524의 평균 픽셀 속도: 91.49 pixels/second
# 객체 526의 평균 픽셀 속도: 76.31 pixels/second
# 객체 527의 평균 픽셀 속도: 81.00 pixels/second
# 객체 528의 평균 픽셀 속도: 61.25 pixels/second
# 객체 529의 평균 픽셀 속도: 92.79 pixels/second
# 객체 530의 평균 픽셀 속도: 73.39 pixels/second
# 객체 535의 평균 픽셀 속도: 88.29 pixels/second
# 객체 537의 평균 픽셀 속도: 62.31 pixels/second
# 객체 541의 평균 픽셀 속도: 98.93 pixels/second
# 객체 543의 평균 픽셀 속도: 68.34 pixels/second
# 객체 547의 평균 픽셀 속도: 75.68 pixels/second
# 객체 548의 평균 픽셀 속도: 99.94 pixels/second
# 객체 552의 평균 픽셀 속도: 91.84 pixels/second
# 객체 557의 평균 픽셀 속도: 53.48 pixels/second
# 객체 558의 평균 픽셀 속도: 103.78 pixels/second
# 객체 559의 평균 픽셀 속도: 80.41 pixels/second
# 객체 560의 평균 픽셀 속도: 57.83 pixels/second
# 객체 561의 평균 픽셀 속도: 80.51 pixels/second
# 객체 562의 평균 픽셀 속도: 85.03 pixels/second
# 객체 563의 평균 픽셀 속도: 60.12 pixels/second
# 객체 564의 평균 픽셀 속도: 80.83 pixels/second
# 객체 565의 평균 픽셀 속도: 94.03 pixels/second
# 객체 566의 평균 픽셀 속도: 84.43 pixels/second
# 객체 567의 평균 픽셀 속도: 90.97 pixels/second
# 객체 568의 평균 픽셀 속도: 0.00 pixels/second
# 객체 569의 평균 픽셀 속도: 11.92 pixels/second
# 객체 570의 평균 픽셀 속도: 18.52 pixels/second
# 객체 571의 평균 픽셀 속도: 109.30 pixels/second
# 객체 573의 평균 픽셀 속도: 15.69 pixels/second
# 객체 574의 평균 픽셀 속도: 47.35 pixels/second
# 객체 575의 평균 픽셀 속도: 88.67 pixels/second
# 객체 576의 평균 픽셀 속도: 102.11 pixels/second
# 객체 577의 평균 픽셀 속도: 78.61 pixels/second
# 객체 578의 평균 픽셀 속도: 67.16 pixels/second
# 객체 579의 평균 픽셀 속도: 10.55 pixels/second
# 객체 580의 평균 픽셀 속도: 0.00 pixels/second
# 객체 581의 평균 픽셀 속도: 89.69 pixels/second
# 객체 584의 평균 픽셀 속도: 0.00 pixels/second
# 객체 587의 평균 픽셀 속도: 241.85 pixels/second
# 객체 589의 평균 픽셀 속도: 12.78 pixels/second
# 객체 591의 평균 픽셀 속도: 138.63 pixels/second
# 객체 592의 평균 픽셀 속도: 36.90 pixels/second
# 객체 594의 평균 픽셀 속도: 58.71 pixels/second
# 객체 595의 평균 픽셀 속도: 39.51 pixels/second
# 객체 599의 평균 픽셀 속도: 74.43 pixels/second
# 객체 603의 평균 픽셀 속도: 0.00 pixels/second
# 객체 605의 평균 픽셀 속도: 96.64 pixels/second
# 객체 606의 평균 픽셀 속도: 86.78 pixels/second
# 객체 607의 평균 픽셀 속도: 20.52 pixels/second
# 객체 609의 평균 픽셀 속도: 49.68 pixels/second
# 객체 611의 평균 픽셀 속도: 82.65 pixels/second
# 객체 612의 평균 픽셀 속도: 82.92 pixels/second
# 객체 613의 평균 픽셀 속도: 79.50 pixels/second
# 객체 614의 평균 픽셀 속도: 13.89 pixels/second
# 객체 615의 평균 픽셀 속도: 86.21 pixels/second
# 객체 617의 평균 픽셀 속도: 83.43 pixels/second
# 객체 618의 평균 픽셀 속도: 50.79 pixels/second
# 객체 619의 평균 픽셀 속도: 37.25 pixels/second
# 객체 622의 평균 픽셀 속도: 8.06 pixels/second
# 객체 623의 평균 픽셀 속도: 67.33 pixels/second
# 객체 624의 평균 픽셀 속도: 47.06 pixels/second
# 객체 627의 평균 픽셀 속도: 60.07 pixels/second
# 객체 629의 평균 픽셀 속도: 96.84 pixels/second
# 객체 630의 평균 픽셀 속도: 74.52 pixels/second
# 객체 632의 평균 픽셀 속도: 111.26 pixels/second
# 객체 634의 평균 픽셀 속도: 114.91 pixels/second
# 객체 636의 평균 픽셀 속도: 0.00 pixels/second
# 객체 640의 평균 픽셀 속도: 74.58 pixels/second
# 객체 641의 평균 픽셀 속도: 66.84 pixels/second
# 객체 643의 평균 픽셀 속도: 75.71 pixels/second
# 객체 649의 평균 픽셀 속도: 0.00 pixels/second
# 객체 651의 평균 픽셀 속도: 89.84 pixels/second
# 객체 652의 평균 픽셀 속도: 110.11 pixels/second
# 객체 653의 평균 픽셀 속도: 80.39 pixels/second
# 객체 656의 평균 픽셀 속도: 91.72 pixels/second
# 객체 658의 평균 픽셀 속도: 164.21 pixels/second
# 객체 659의 평균 픽셀 속도: 21.87 pixels/second
# 객체 663의 평균 픽셀 속도: 70.20 pixels/second
# 객체 665의 평균 픽셀 속도: 92.31 pixels/second
# 객체 666의 평균 픽셀 속도: 67.43 pixels/second
# 객체 668의 평균 픽셀 속도: 0.00 pixels/second
# 객체 669의 평균 픽셀 속도: 81.31 pixels/second
# 객체 671의 평균 픽셀 속도: 102.36 pixels/second
# 객체 677의 평균 픽셀 속도: 88.26 pixels/second
# 객체 678의 평균 픽셀 속도: 65.82 pixels/second
# 객체 679의 평균 픽셀 속도: 66.18 pixels/second
# 객체 682의 평균 픽셀 속도: 0.00 pixels/second
# 객체 684의 평균 픽셀 속도: 94.77 pixels/second
# 객체 685의 평균 픽셀 속도: 0.00 pixels/second
# 객체 686의 평균 픽셀 속도: 122.09 pixels/second
# 객체 687의 평균 픽셀 속도: 53.46 pixels/second
# 객체 689의 평균 픽셀 속도: 76.86 pixels/second
# 객체 690의 평균 픽셀 속도: 0.00 pixels/second
# 객체 691의 평균 픽셀 속도: 87.27 pixels/second
# 객체 692의 평균 픽셀 속도: 107.35 pixels/second
# 객체 694의 평균 픽셀 속도: 34.94 pixels/second
# 객체 697의 평균 픽셀 속도: 99.80 pixels/second
# 객체 699의 평균 픽셀 속도: 0.00 pixels/second
# 객체 702의 평균 픽셀 속도: 78.79 pixels/second
# 객체 704의 평균 픽셀 속도: 74.40 pixels/second
# 객체 707의 평균 픽셀 속도: 116.90 pixels/second
# 객체 709의 평균 픽셀 속도: 85.43 pixels/second
# 객체 711의 평균 픽셀 속도: 152.56 pixels/second
# 객체 713의 평균 픽셀 속도: 78.45 pixels/second
# 객체 717의 평균 픽셀 속도: 0.00 pixels/second
# 객체 719의 평균 픽셀 속도: 82.82 pixels/second
# 객체 720의 평균 픽셀 속도: 48.77 pixels/second
# 객체 721의 평균 픽셀 속도: 99.44 pixels/second
# 객체 722의 평균 픽셀 속도: 0.00 pixels/second
# 객체 726의 평균 픽셀 속도: 0.00 pixels/second
# 객체 727의 평균 픽셀 속도: 195.43 pixels/second
# 객체 729의 평균 픽셀 속도: 0.00 pixels/second
# 객체 730의 평균 픽셀 속도: 64.02 pixels/second
# 객체 731의 평균 픽셀 속도: 19.91 pixels/second
# 객체 732의 평균 픽셀 속도: 105.33 pixels/second
# 객체 736의 평균 픽셀 속도: 0.00 pixels/second
# 객체 740의 평균 픽셀 속도: 73.94 pixels/second
# 객체 741의 평균 픽셀 속도: 60.31 pixels/second
# 객체 742의 평균 픽셀 속도: 16.11 pixels/second
# 객체 744의 평균 픽셀 속도: 0.00 pixels/second
# 객체 748의 평균 픽셀 속도: 79.05 pixels/second
# 객체 749의 평균 픽셀 속도: 0.00 pixels/second
# 객체 750의 평균 픽셀 속도: 93.86 pixels/second
# 객체 751의 평균 픽셀 속도: 21.12 pixels/second
# 객체 752의 평균 픽셀 속도: 135.13 pixels/second
# 객체 753의 평균 픽셀 속도: 94.07 pixels/second
# 객체 755의 평균 픽셀 속도: 119.57 pixels/second
# 객체 756의 평균 픽셀 속도: 79.15 pixels/second
# 객체 757의 평균 픽셀 속도: 66.97 pixels/second
# 객체 758의 평균 픽셀 속도: 106.91 pixels/second
# 객체 762의 평균 픽셀 속도: 0.00 pixels/second
# 객체 763의 평균 픽셀 속도: 118.61 pixels/second
# 객체 766의 평균 픽셀 속도: 0.00 pixels/second
# 객체 767의 평균 픽셀 속도: 83.31 pixels/second
# 객체 772의 평균 픽셀 속도: 74.16 pixels/second
# 객체 774의 평균 픽셀 속도: 95.00 pixels/second
# 객체 777의 평균 픽셀 속도: 105.15 pixels/second
# 객체 778의 평균 픽셀 속도: 148.64 pixels/second
# 객체 783의 평균 픽셀 속도: 73.54 pixels/second
# 객체 784의 평균 픽셀 속도: 42.37 pixels/second
# 객체 786의 평균 픽셀 속도: 0.00 pixels/second
# 객체 792의 평균 픽셀 속도: 99.31 pixels/second
# 객체 796의 평균 픽셀 속도: 0.00 pixels/second
# 객체 797의 평균 픽셀 속도: 115.23 pixels/second
# 객체 800의 평균 픽셀 속도: 8.48 pixels/second
# 객체 805의 평균 픽셀 속도: 48.87 pixels/second
# 객체 813의 평균 픽셀 속도: 0.00 pixels/second
# 객체 818의 평균 픽셀 속도: 122.76 pixels/second
# 객체 821의 평균 픽셀 속도: 69.98 pixels/second
# 객체 832의 평균 픽셀 속도: 71.98 pixels/second
# 객체 839의 평균 픽셀 속도: 95.52 pixels/second
# 객체 840의 평균 픽셀 속도: 73.88 pixels/second
# 객체 844의 평균 픽셀 속도: 67.26 pixels/second
# 객체 845의 평균 픽셀 속도: 107.12 pixels/second
# 객체 849의 평균 픽셀 속도: 79.76 pixels/second
# 객체 850의 평균 픽셀 속도: 101.59 pixels/second
# 객체 862의 평균 픽셀 속도: 72.01 pixels/second
# 객체 870의 평균 픽셀 속도: 159.94 pixels/second
# 객체 874의 평균 픽셀 속도: 176.36 pixels/second
# 객체 879의 평균 픽셀 속도: 57.23 pixels/second
# 객체 880의 평균 픽셀 속도: 138.08 pixels/second
# 객체 881의 평균 픽셀 속도: 18.30 pixels/second
# 객체 882의 평균 픽셀 속도: 47.57 pixels/second
# 객체 883의 평균 픽셀 속도: 62.76 pixels/second
# 객체 886의 평균 픽셀 속도: 89.41 pixels/second
# 객체 888의 평균 픽셀 속도: 92.79 pixels/second
# 객체 891의 평균 픽셀 속도: 96.86 pixels/second
# 객체 892의 평균 픽셀 속도: 138.03 pixels/second
# 객체 895의 평균 픽셀 속도: 47.06 pixels/second
# 객체 896의 평균 픽셀 속도: 82.62 pixels/second
# 객체 898의 평균 픽셀 속도: 85.38 pixels/second
# 객체 899의 평균 픽셀 속도: 13.68 pixels/second
# 객체 900의 평균 픽셀 속도: 77.62 pixels/second
# 객체 902의 평균 픽셀 속도: 75.58 pixels/second
# 객체 903의 평균 픽셀 속도: 158.50 pixels/second
# 객체 905의 평균 픽셀 속도: 84.16 pixels/second
# 객체 906의 평균 픽셀 속도: 71.80 pixels/second
# 객체 907의 평균 픽셀 속도: 67.03 pixels/second
# 객체 908의 평균 픽셀 속도: 86.85 pixels/second
# 객체 909의 평균 픽셀 속도: 87.91 pixels/second
# 객체 910의 평균 픽셀 속도: 62.49 pixels/second
# 객체 913의 평균 픽셀 속도: 38.27 pixels/second
# 객체 914의 평균 픽셀 속도: 28.14 pixels/second
# 객체 919의 평균 픽셀 속도: 55.50 pixels/second
# 객체 921의 평균 픽셀 속도: 35.48 pixels/second
# 객체 922의 평균 픽셀 속도: 45.09 pixels/second
# 객체 923의 평균 픽셀 속도: 87.19 pixels/second
# 객체 924의 평균 픽셀 속도: 81.16 pixels/second
# 객체 925의 평균 픽셀 속도: 133.14 pixels/second
# 객체 926의 평균 픽셀 속도: 83.23 pixels/second
# 객체 928의 평균 픽셀 속도: 16.83 pixels/second
# 객체 930의 평균 픽셀 속도: 79.49 pixels/second
# 객체 931의 평균 픽셀 속도: 24.37 pixels/second
# 객체 932의 평균 픽셀 속도: 101.30 pixels/second
# 객체 933의 평균 픽셀 속도: 77.21 pixels/second
# 객체 934의 평균 픽셀 속도: 79.85 pixels/second
# 객체 935의 평균 픽셀 속도: 72.17 pixels/second
# 객체 936의 평균 픽셀 속도: 62.96 pixels/second
# 객체 938의 평균 픽셀 속도: 74.99 pixels/second
# 객체 940의 평균 픽셀 속도: 14.87 pixels/second
# 객체 941의 평균 픽셀 속도: 58.89 pixels/second
# 객체 943의 평균 픽셀 속도: 92.80 pixels/second
# 객체 945의 평균 픽셀 속도: 11.59 pixels/second
# 객체 949의 평균 픽셀 속도: 72.87 pixels/second
# 객체 951의 평균 픽셀 속도: 66.69 pixels/second
# 객체 955의 평균 픽셀 속도: 83.23 pixels/second
# 객체 957의 평균 픽셀 속도: 64.56 pixels/second
# 객체 958의 평균 픽셀 속도: 13.93 pixels/second
# 객체 960의 평균 픽셀 속도: 74.42 pixels/second
# 객체 963의 평균 픽셀 속도: 98.71 pixels/second
# 객체 964의 평균 픽셀 속도: 65.02 pixels/second
# 객체 966의 평균 픽셀 속도: 76.05 pixels/second
# 객체 969의 평균 픽셀 속도: 80.21 pixels/second
# 객체 970의 평균 픽셀 속도: 66.59 pixels/second
# 객체 971의 평균 픽셀 속도: 9.53 pixels/second
# 객체 972의 평균 픽셀 속도: 0.00 pixels/second
# 객체 975의 평균 픽셀 속도: 65.81 pixels/second
# 객체 976의 평균 픽셀 속도: 12.65 pixels/second
# 객체 978의 평균 픽셀 속도: 77.10 pixels/second
# 객체 979의 평균 픽셀 속도: 67.95 pixels/second
# 객체 980의 평균 픽셀 속도: 87.18 pixels/second
# 객체 981의 평균 픽셀 속도: 11.67 pixels/second
# 객체 983의 평균 픽셀 속도: 11.49 pixels/second
# 객체 985의 평균 픽셀 속도: 76.35 pixels/second
# 객체 988의 평균 픽셀 속도: 76.74 pixels/second
# 객체 990의 평균 픽셀 속도: 66.25 pixels/second
# 객체 991의 평균 픽셀 속도: 52.47 pixels/second
# 객체 992의 평균 픽셀 속도: 70.82 pixels/second
# 객체 993의 평균 픽셀 속도: 111.89 pixels/second
# 객체 996의 평균 픽셀 속도: 57.89 pixels/second
# 객체 998의 평균 픽셀 속도: 0.00 pixels/second
# 객체 1000의 평균 픽셀 속도: 45.91 pixels/second
# 객체 1001의 평균 픽셀 속도: 105.30 pixels/second
# 객체 1003의 평균 픽셀 속도: 73.71 pixels/second
# 객체 1004의 평균 픽셀 속도: 54.73 pixels/second
# 객체 1007의 평균 픽셀 속도: 65.81 pixels/second
# 객체 1008의 평균 픽셀 속도: 103.58 pixels/second
# 객체 1009의 평균 픽셀 속도: 68.71 pixels/second
# 객체 1010의 평균 픽셀 속도: 123.79 pixels/second
# 객체 1011의 평균 픽셀 속도: 34.95 pixels/second
# 객체 1014의 평균 픽셀 속도: 88.44 pixels/second
# 객체 1015의 평균 픽셀 속도: 86.21 pixels/second
# 객체 1016의 평균 픽셀 속도: 11.65 pixels/second
# 객체 1018의 평균 픽셀 속도: 106.97 pixels/second
# 객체 1020의 평균 픽셀 속도: 69.22 pixels/second
# 객체 1021의 평균 픽셀 속도: 95.48 pixels/second
# 객체 1022의 평균 픽셀 속도: 60.73 pixels/second
# 객체 1023의 평균 픽셀 속도: 56.61 pixels/second
# 객체 1026의 평균 픽셀 속도: 68.89 pixels/second
# 객체 1028의 평균 픽셀 속도: 91.38 pixels/second
# 객체 1031의 평균 픽셀 속도: 79.65 pixels/second
# 객체 1032의 평균 픽셀 속도: 104.32 pixels/second
# 객체 1033의 평균 픽셀 속도: 73.16 pixels/second
# 객체 1034의 평균 픽셀 속도: 87.83 pixels/second
# 객체 1035의 평균 픽셀 속도: 44.20 pixels/second
# 객체 1038의 평균 픽셀 속도: 87.21 pixels/second
# 객체 1040의 평균 픽셀 속도: 72.91 pixels/second
# 객체 1042의 평균 픽셀 속도: 101.67 pixels/second
# 객체 1043의 평균 픽셀 속도: 29.34 pixels/second
# 객체 1047의 평균 픽셀 속도: 87.40 pixels/second
# 객체 1048의 평균 픽셀 속도: 39.88 pixels/second
# 객체 1049의 평균 픽셀 속도: 0.00 pixels/second
# 객체 1050의 평균 픽셀 속도: 76.86 pixels/second
# 객체 1052의 평균 픽셀 속도: 415.60 pixels/second
# 객체 1053의 평균 픽셀 속도: 68.05 pixels/second
# 객체 1056의 평균 픽셀 속도: 69.06 pixels/second
# 객체 1060의 평균 픽셀 속도: 69.83 pixels/second
# 객체 1061의 평균 픽셀 속도: 74.63 pixels/second
# 객체 1062의 평균 픽셀 속도: 0.00 pixels/second
# 객체 1069의 평균 픽셀 속도: 0.00 pixels/second
# 객체 1070의 평균 픽셀 속도: 219.82 pixels/second
# 객체 1072의 평균 픽셀 속도: 113.85 pixels/second
# 객체 1073의 평균 픽셀 속도: 88.05 pixels/second
# 객체 1077의 평균 픽셀 속도: 134.52 pixels/second
# 객체 1078의 평균 픽셀 속도: 72.64 pixels/second
# 객체 1079의 평균 픽셀 속도: 24.21 pixels/second
# 객체 1080의 평균 픽셀 속도: 87.11 pixels/second
# 객체 1081의 평균 픽셀 속도: 109.71 pixels/second
# 객체 1082의 평균 픽셀 속도: 304.64 pixels/second
# 객체 1084의 평균 픽셀 속도: 47.20 pixels/second
# 객체 1085의 평균 픽셀 속도: 26.51 pixels/second
# 객체 1086의 평균 픽셀 속도: 0.00 pixels/second
# 객체 1087의 평균 픽셀 속도: 122.41 pixels/second
# 객체 1089의 평균 픽셀 속도: 25.79 pixels/second
# 객체 1090의 평균 픽셀 속도: 34.14 pixels/second
# 객체 1091의 평균 픽셀 속도: 57.54 pixels/second
# 객체 1093의 평균 픽셀 속도: 188.68 pixels/second
# 객체 1095의 평균 픽셀 속도: 14.52 pixels/second
# 객체 1096의 평균 픽셀 속도: 94.94 pixels/second
# 객체 1097의 평균 픽셀 속도: 0.00 pixels/second
# 객체 1100의 평균 픽셀 속도: 0.00 pixels/second
# 객체 1101의 평균 픽셀 속도: 66.52 pixels/second
# 객체 1103의 평균 픽셀 속도: 68.65 pixels/second
# 객체 1104의 평균 픽셀 속도: 75.69 pixels/second
# 객체 1105의 평균 픽셀 속도: 94.21 pixels/second
# 객체 1107의 평균 픽셀 속도: 88.26 pixels/second
# 객체 1108의 평균 픽셀 속도: 57.96 pixels/second
# 객체 1110의 평균 픽셀 속도: 82.23 pixels/second
# 객체 1112의 평균 픽셀 속도: 90.07 pixels/second
# 객체 1114의 평균 픽셀 속도: 82.14 pixels/second
# 객체 1116의 평균 픽셀 속도: 74.46 pixels/second
# 객체 1117의 평균 픽셀 속도: 41.76 pixels/second
# 객체 1118의 평균 픽셀 속도: 89.79 pixels/second
# 객체 1119의 평균 픽셀 속도: 101.96 pixels/second
# 객체 1120의 평균 픽셀 속도: 373.14 pixels/second
# 객체 1122의 평균 픽셀 속도: 75.29 pixels/second
# 객체 1124의 평균 픽셀 속도: 345.40 pixels/second
# 객체 1125의 평균 픽셀 속도: 0.00 pixels/second
# 객체 1126의 평균 픽셀 속도: 40.67 pixels/second
# 객체 1127의 평균 픽셀 속도: 68.50 pixels/second
# 객체 1129의 평균 픽셀 속도: 89.97 pixels/second
# 객체 1130의 평균 픽셀 속도: 54.72 pixels/second
# 객체 1131의 평균 픽셀 속도: 63.76 pixels/second
# 객체 1132의 평균 픽셀 속도: 78.03 pixels/second
# 객체 1133의 평균 픽셀 속도: 73.90 pixels/second
# 객체 1135의 평균 픽셀 속도: 42.71 pixels/second
# 객체 1136의 평균 픽셀 속도: 97.22 pixels/second
# 객체 1138의 평균 픽셀 속도: 79.86 pixels/second
# 객체 1140의 평균 픽셀 속도: 72.54 pixels/second
# 객체 1141의 평균 픽셀 속도: 73.40 pixels/second
# 객체 1142의 평균 픽셀 속도: 29.71 pixels/second
# 객체 1145의 평균 픽셀 속도: 66.34 pixels/second
# 객체 1146의 평균 픽셀 속도: 0.00 pixels/second
# 객체 1148의 평균 픽셀 속도: 293.98 pixels/second
# 객체 1149의 평균 픽셀 속도: 379.74 pixels/second
# 객체 1150의 평균 픽셀 속도: 113.58 pixels/second
# 객체 1152의 평균 픽셀 속도: 99.96 pixels/second
# 객체 1157의 평균 픽셀 속도: 325.11 pixels/second
# 객체 1158의 평균 픽셀 속도: 42.23 pixels/second
# 객체 1160의 평균 픽셀 속도: 16.63 pixels/second
# 객체 1162의 평균 픽셀 속도: 81.94 pixels/second
# 객체 1164의 평균 픽셀 속도: 251.11 pixels/second
# 객체 1166의 평균 픽셀 속도: 62.43 pixels/second
# 객체 1167의 평균 픽셀 속도: 83.51 pixels/second
# 객체 1168의 평균 픽셀 속도: 62.22 pixels/second
# 객체 1169의 평균 픽셀 속도: 78.29 pixels/second
# 객체 1175의 평균 픽셀 속도: 25.86 pixels/second
# 객체 1176의 평균 픽셀 속도: 348.20 pixels/second
# 객체 1178의 평균 픽셀 속도: 24.84 pixels/second
# 객체 1179의 평균 픽셀 속도: 71.27 pixels/second
# 객체 1180의 평균 픽셀 속도: 158.26 pixels/second
# 객체 1181의 평균 픽셀 속도: 41.06 pixels/second
# 객체 1182의 평균 픽셀 속도: 80.93 pixels/second
# 객체 1183의 평균 픽셀 속도: 64.53 pixels/second
# 객체 1186의 평균 픽셀 속도: 360.98 pixels/second
# 객체 1190의 평균 픽셀 속도: 62.85 pixels/second
# 객체 1191의 평균 픽셀 속도: 107.05 pixels/second
# 객체 1192의 평균 픽셀 속도: 27.60 pixels/second
# 객체 1193의 평균 픽셀 속도: 108.69 pixels/second
# 객체 1196의 평균 픽셀 속도: 74.18 pixels/second
# 객체 1198의 평균 픽셀 속도: 7.31 pixels/second
# 객체 1203의 평균 픽셀 속도: 90.16 pixels/second
# 객체 1207의 평균 픽셀 속도: 62.62 pixels/second
# 객체 1208의 평균 픽셀 속도: 276.10 pixels/second
# 객체 1209의 평균 픽셀 속도: 23.15 pixels/second
# 객체 1216의 평균 픽셀 속도: 96.92 pixels/second
# 객체 1218의 평균 픽셀 속도: 50.41 pixels/second
# 객체 1220의 평균 픽셀 속도: 0.00 pixels/second
# 객체 1221의 평균 픽셀 속도: 88.01 pixels/second
# 객체 1226의 평균 픽셀 속도: 96.94 pixels/second
# 객체 1228의 평균 픽셀 속도: 85.02 pixels/second
# 객체 1229의 평균 픽셀 속도: 356.90 pixels/second
# 객체 1232의 평균 픽셀 속도: 80.16 pixels/second
# 객체 1233의 평균 픽셀 속도: 63.89 pixels/second
# 객체 1234의 평균 픽셀 속도: 13.30 pixels/second
# 객체 1238의 평균 픽셀 속도: 561.47 pixels/second
# 객체 1239의 평균 픽셀 속도: 317.32 pixels/second
# 객체 1240의 평균 픽셀 속도: 16.95 pixels/second
# 객체 1242의 평균 픽셀 속도: 260.75 pixels/second
# 객체 1243의 평균 픽셀 속도: 227.79 pixels/second
# 객체 1246의 평균 픽셀 속도: 77.44 pixels/second
# 객체 1248의 평균 픽셀 속도: 67.86 pixels/second
# 객체 1249의 평균 픽셀 속도: 75.70 pixels/second
# 객체 1250의 평균 픽셀 속도: 358.93 pixels/second
# 객체 1251의 평균 픽셀 속도: 75.78 pixels/second
# 객체 1252의 평균 픽셀 속도: 76.74 pixels/second
# 객체 1253의 평균 픽셀 속도: 35.20 pixels/second
# 객체 1255의 평균 픽셀 속도: 72.93 pixels/second
# 객체 1256의 평균 픽셀 속도: 12.28 pixels/second
# 객체 1257의 평균 픽셀 속도: 19.44 pixels/second
# 객체 1259의 평균 픽셀 속도: 86.26 pixels/second
# 객체 1261의 평균 픽셀 속도: 72.64 pixels/second
# 객체 1263의 평균 픽셀 속도: 37.79 pixels/second
# 객체 1264의 평균 픽셀 속도: 373.74 pixels/second
# 객체 1265의 평균 픽셀 속도: 75.18 pixels/second
# 객체 1266의 평균 픽셀 속도: 34.81 pixels/second
# 객체 1268의 평균 픽셀 속도: 91.29 pixels/second
# 객체 1269의 평균 픽셀 속도: 79.80 pixels/second
# 객체 1272의 평균 픽셀 속도: 43.57 pixels/second
# 객체 1273의 평균 픽셀 속도: 17.83 pixels/second
# 객체 1275의 평균 픽셀 속도: 0.00 pixels/second
# 객체 1278의 평균 픽셀 속도: 73.49 pixels/second
# 객체 1279의 평균 픽셀 속도: 28.93 pixels/second
# 객체 1280의 평균 픽셀 속도: 32.13 pixels/second
# 객체 1283의 평균 픽셀 속도: 76.32 pixels/second
# 객체 1285의 평균 픽셀 속도: 58.73 pixels/second
# 객체 1286의 평균 픽셀 속도: 81.92 pixels/second
# 객체 1288의 평균 픽셀 속도: 83.42 pixels/second
# 객체 1290의 평균 픽셀 속도: 44.60 pixels/second
# 객체 1291의 평균 픽셀 속도: 81.11 pixels/second
# 객체 1292의 평균 픽셀 속도: 141.76 pixels/second
# 객체 1295의 평균 픽셀 속도: 59.00 pixels/second
# 객체 1298의 평균 픽셀 속도: 81.37 pixels/second
# 객체 1300의 평균 픽셀 속도: 79.02 pixels/second
# 객체 1301의 평균 픽셀 속도: 68.17 pixels/second
# 객체 1303의 평균 픽셀 속도: 95.74 pixels/second
# 객체 1304의 평균 픽셀 속도: 81.32 pixels/second
# 객체 1305의 평균 픽셀 속도: 17.98 pixels/second
# 객체 1307의 평균 픽셀 속도: 57.80 pixels/second
# 객체 1308의 평균 픽셀 속도: 74.28 pixels/second
# 객체 1309의 평균 픽셀 속도: 80.86 pixels/second
# 객체 1310의 평균 픽셀 속도: 12.67 pixels/second
# 객체 1312의 평균 픽셀 속도: 13.81 pixels/second
# 객체 1314의 평균 픽셀 속도: 43.67 pixels/second
# 객체 1315의 평균 픽셀 속도: 54.69 pixels/second
# 객체 1316의 평균 픽셀 속도: 90.62 pixels/second
# 객체 1319의 평균 픽셀 속도: 82.19 pixels/second
# 객체 1321의 평균 픽셀 속도: 16.34 pixels/second
# 객체 1323의 평균 픽셀 속도: 36.50 pixels/second
# 객체 1324의 평균 픽셀 속도: 80.66 pixels/second
# 객체 1327의 평균 픽셀 속도: 28.44 pixels/second
# 객체 1328의 평균 픽셀 속도: 419.04 pixels/second
# 객체 1329의 평균 픽셀 속도: 65.89 pixels/second
# 객체 1330의 평균 픽셀 속도: 58.91 pixels/second
# 객체 1332의 평균 픽셀 속도: 96.10 pixels/second
# 객체 1336의 평균 픽셀 속도: 65.97 pixels/second
# 객체 1338의 평균 픽셀 속도: 98.90 pixels/second
# 객체 1339의 평균 픽셀 속도: 5.85 pixels/second
# 객체 1340의 평균 픽셀 속도: 461.02 pixels/second
# 객체 1342의 평균 픽셀 속도: 53.24 pixels/second
# 객체 1343의 평균 픽셀 속도: 51.34 pixels/second
# 객체 1344의 평균 픽셀 속도: 71.33 pixels/second
# 객체 1345의 평균 픽셀 속도: 17.64 pixels/second
# 객체 1346의 평균 픽셀 속도: 49.05 pixels/second
# 객체 1347의 평균 픽셀 속도: 54.96 pixels/second
# 객체 1348의 평균 픽셀 속도: 73.89 pixels/second
# 객체 1352의 평균 픽셀 속도: 68.43 pixels/second
# 객체 1354의 평균 픽셀 속도: 53.96 pixels/second
# 객체 1355의 평균 픽셀 속도: 60.17 pixels/second
# 객체 1357의 평균 픽셀 속도: 0.00 pixels/second
# 객체 1358의 평균 픽셀 속도: 195.98 pixels/second
# 객체 1360의 평균 픽셀 속도: 105.27 pixels/second
# 객체 1361의 평균 픽셀 속도: 52.29 pixels/second
# 객체 1364의 평균 픽셀 속도: 17.59 pixels/second
# 객체 1365의 평균 픽셀 속도: 40.46 pixels/second
# 객체 1366의 평균 픽셀 속도: 10.76 pixels/second
# 객체 1367의 평균 픽셀 속도: 73.02 pixels/second
# 객체 1368의 평균 픽셀 속도: 74.10 pixels/second
# 객체 1370의 평균 픽셀 속도: 85.33 pixels/second
# 객체 1371의 평균 픽셀 속도: 48.88 pixels/second
# 객체 1372의 평균 픽셀 속도: 421.08 pixels/second
# 객체 1375의 평균 픽셀 속도: 3.44 pixels/second
# 객체 1376의 평균 픽셀 속도: 39.89 pixels/second
# 객체 1377의 평균 픽셀 속도: 920.13 pixels/second
# 객체 1379의 평균 픽셀 속도: 78.31 pixels/second
# 객체 1380의 평균 픽셀 속도: 73.75 pixels/second
# 객체 1382의 평균 픽셀 속도: 75.44 pixels/second
# 객체 1386의 평균 픽셀 속도: 405.63 pixels/second
# 객체 1389의 평균 픽셀 속도: 852.49 pixels/second
# 객체 1390의 평균 픽셀 속도: 79.22 pixels/second
# 객체 1391의 평균 픽셀 속도: 93.75 pixels/second
# 객체 1392의 평균 픽셀 속도: 721.24 pixels/second
# 객체 1393의 평균 픽셀 속도: 82.16 pixels/second
# 객체 1394의 평균 픽셀 속도: 105.36 pixels/second
# 객체 1399의 평균 픽셀 속도: 35.34 pixels/second
# 객체 1400의 평균 픽셀 속도: 107.01 pixels/second
# 객체 1401의 평균 픽셀 속도: 64.99 pixels/second
# 객체 1403의 평균 픽셀 속도: 125.42 pixels/second
# 객체 1404의 평균 픽셀 속도: 63.28 pixels/second
# 객체 1405의 평균 픽셀 속도: 0.00 pixels/second
# 객체 1412의 평균 픽셀 속도: 75.87 pixels/second
# 객체 1414의 평균 픽셀 속도: 0.00 pixels/second
# 객체 1415의 평균 픽셀 속도: 35.39 pixels/second
# 객체 1416의 평균 픽셀 속도: 194.95 pixels/second
# 객체 1418의 평균 픽셀 속도: 91.49 pixels/second
# 객체 1421의 평균 픽셀 속도: 106.49 pixels/second
# 객체 1422의 평균 픽셀 속도: 140.08 pixels/second
# 객체 1423의 평균 픽셀 속도: 68.53 pixels/second
# 객체 1427의 평균 픽셀 속도: 58.53 pixels/second
# 객체 1428의 평균 픽셀 속도: 72.19 pixels/second
# 객체 1429의 평균 픽셀 속도: 71.70 pixels/second
# 객체 1430의 평균 픽셀 속도: 64.46 pixels/second
# 객체 1431의 평균 픽셀 속도: 0.00 pixels/second
# 객체 1432의 평균 픽셀 속도: 78.87 pixels/second
# 객체 1435의 평균 픽셀 속도: 0.00 pixels/second
# 객체 1436의 평균 픽셀 속도: 64.50 pixels/second
# 객체 1437의 평균 픽셀 속도: 93.09 pixels/second
# 객체 1438의 평균 픽셀 속도: 92.09 pixels/second
# 객체 1439의 평균 픽셀 속도: 73.51 pixels/second
# 객체 1440의 평균 픽셀 속도: 57.20 pixels/second
# 객체 1443의 평균 픽셀 속도: 13.97 pixels/second
# 객체 1444의 평균 픽셀 속도: 57.11 pixels/second
# 객체 1445의 평균 픽셀 속도: 72.47 pixels/second
# 객체 1446의 평균 픽셀 속도: 62.43 pixels/second
# 객체 1447의 평균 픽셀 속도: 84.71 pixels/second
# 객체 1448의 평균 픽셀 속도: 33.80 pixels/second
# 객체 1449의 평균 픽셀 속도: 262.33 pixels/second
# 객체 1450의 평균 픽셀 속도: 66.38 pixels/second
# 객체 1451의 평균 픽셀 속도: 534.82 pixels/second
# 객체 1452의 평균 픽셀 속도: 56.02 pixels/second
# 객체 1454의 평균 픽셀 속도: 59.02 pixels/second
# 객체 1455의 평균 픽셀 속도: 4.10 pixels/second
# 객체 1457의 평균 픽셀 속도: 58.89 pixels/second
# 객체 1458의 평균 픽셀 속도: 74.71 pixels/second
# 객체 1459의 평균 픽셀 속도: 40.31 pixels/second
# 객체 1460의 평균 픽셀 속도: 60.27 pixels/second
# 객체 1461의 평균 픽셀 속도: 51.58 pixels/second
# 객체 1462의 평균 픽셀 속도: 40.07 pixels/second
# 객체 1463의 평균 픽셀 속도: 54.77 pixels/second
# 객체 1464의 평균 픽셀 속도: 19.99 pixels/second
# 객체 1465의 평균 픽셀 속도: 51.03 pixels/second
# 객체 1466의 평균 픽셀 속도: 16.14 pixels/second
# 객체 1467의 평균 픽셀 속도: 249.79 pixels/second
# 객체 1468의 평균 픽셀 속도: 90.96 pixels/second
# 객체 1469의 평균 픽셀 속도: 73.81 pixels/second
# 객체 1471의 평균 픽셀 속도: 518.57 pixels/second
# 객체 1472의 평균 픽셀 속도: 103.92 pixels/second
# 객체 1473의 평균 픽셀 속도: 74.07 pixels/second
# 객체 1477의 평균 픽셀 속도: 67.51 pixels/second
# 객체 1479의 평균 픽셀 속도: 55.62 pixels/second
# 객체 1481의 평균 픽셀 속도: 0.00 pixels/second
# 객체 1483의 평균 픽셀 속도: 250.32 pixels/second
# 객체 1484의 평균 픽셀 속도: 93.42 pixels/second
# 객체 1485의 평균 픽셀 속도: 499.29 pixels/second
# 객체 1486의 평균 픽셀 속도: 78.22 pixels/second
# 객체 1487의 평균 픽셀 속도: 77.63 pixels/second
# 객체 1490의 평균 픽셀 속도: 48.69 pixels/second
# 객체 1493의 평균 픽셀 속도: 57.67 pixels/second
# 객체 1494의 평균 픽셀 속도: 626.85 pixels/second
# 객체 1496의 평균 픽셀 속도: 73.64 pixels/second
# 객체 1497의 평균 픽셀 속도: 418.65 pixels/second
# 객체 1498의 평균 픽셀 속도: 65.83 pixels/second
# 객체 1499의 평균 픽셀 속도: 18.76 pixels/second
# 객체 1500의 평균 픽셀 속도: 58.14 pixels/second
# 객체 1501의 평균 픽셀 속도: 79.27 pixels/second
# 객체 1502의 평균 픽셀 속도: 54.77 pixels/second
# 객체 1503의 평균 픽셀 속도: 11.76 pixels/second
# 객체 1504의 평균 픽셀 속도: 11.17 pixels/second
# 객체 1506의 평균 픽셀 속도: 83.25 pixels/second
# 객체 1508의 평균 픽셀 속도: 83.52 pixels/second
# 객체 1510의 평균 픽셀 속도: 69.09 pixels/second
# 객체 1511의 평균 픽셀 속도: 36.60 pixels/second
# 객체 1512의 평균 픽셀 속도: 69.66 pixels/second
# 객체 1513의 평균 픽셀 속도: 25.81 pixels/second
# 객체 1515의 평균 픽셀 속도: 62.86 pixels/second
# 객체 1516의 평균 픽셀 속도: 126.55 pixels/second
# 객체 1517의 평균 픽셀 속도: 58.81 pixels/second
# 객체 1518의 평균 픽셀 속도: 89.88 pixels/second
# 객체 1519의 평균 픽셀 속도: 83.86 pixels/second
# 객체 1520의 평균 픽셀 속도: 95.91 pixels/second
# 객체 1527의 평균 픽셀 속도: 63.63 pixels/second
# 객체 1528의 평균 픽셀 속도: 72.25 pixels/second
# 객체 1530의 평균 픽셀 속도: 121.22 pixels/second
# 객체 1531의 평균 픽셀 속도: 75.78 pixels/second
# 객체 1532의 평균 픽셀 속도: 78.58 pixels/second
# 객체 1534의 평균 픽셀 속도: 73.75 pixels/second
# 객체 1535의 평균 픽셀 속도: 79.52 pixels/second
# 객체 1537의 평균 픽셀 속도: 90.69 pixels/second
# 객체 1541의 평균 픽셀 속도: 2.61 pixels/second
# 객체 1544의 평균 픽셀 속도: 22.20 pixels/second
# 객체 1546의 평균 픽셀 속도: 63.37 pixels/second
# 객체 1547의 평균 픽셀 속도: 70.22 pixels/second
# 객체 1549의 평균 픽셀 속도: 20.62 pixels/second
# 객체 1550의 평균 픽셀 속도: 59.79 pixels/second
# 객체 1551의 평균 픽셀 속도: 100.40 pixels/second
# 객체 1552의 평균 픽셀 속도: 76.79 pixels/second
# 객체 1555의 평균 픽셀 속도: 21.54 pixels/second
# 객체 1557의 평균 픽셀 속도: 92.79 pixels/second
# 객체 1558의 평균 픽셀 속도: 102.31 pixels/second
# 객체 1560의 평균 픽셀 속도: 56.31 pixels/second
# 객체 1563의 평균 픽셀 속도: 91.27 pixels/second
# 객체 1564의 평균 픽셀 속도: 64.88 pixels/second
# 객체 1565의 평균 픽셀 속도: 49.94 pixels/second
# 객체 1566의 평균 픽셀 속도: 32.32 pixels/second
# 객체 1567의 평균 픽셀 속도: 84.85 pixels/second
# 객체 1570의 평균 픽셀 속도: 89.04 pixels/second
# 객체 1571의 평균 픽셀 속도: 67.78 pixels/second
# 객체 1574의 평균 픽셀 속도: 92.33 pixels/second
# 객체 1575의 평균 픽셀 속도: 72.54 pixels/second
# 객체 1577의 평균 픽셀 속도: 67.83 pixels/second
# 객체 1578의 평균 픽셀 속도: 66.75 pixels/second
# 객체 1581의 평균 픽셀 속도: 89.96 pixels/second
# 객체 1583의 평균 픽셀 속도: 89.39 pixels/second
# 객체 1586의 평균 픽셀 속도: 90.08 pixels/second
# 객체 1587의 평균 픽셀 속도: 56.95 pixels/second
# 객체 1589의 평균 픽셀 속도: 87.77 pixels/second
# 객체 1591의 평균 픽셀 속도: 128.41 pixels/second
# 객체 1592의 평균 픽셀 속도: 58.44 pixels/second
# 객체 1595의 평균 픽셀 속도: 172.68 pixels/second
# 객체 1599의 평균 픽셀 속도: 87.65 pixels/second
# 객체 1601의 평균 픽셀 속도: 83.59 pixels/second
# 객체 1603의 평균 픽셀 속도: 69.42 pixels/second
# 객체 1604의 평균 픽셀 속도: 76.27 pixels/second
# 객체 1606의 평균 픽셀 속도: 90.91 pixels/second
# 객체 1608의 평균 픽셀 속도: 76.22 pixels/second
# 객체 1609의 평균 픽셀 속도: 76.01 pixels/second
# 객체 1610의 평균 픽셀 속도: 121.02 pixels/second
# 객체 1611의 평균 픽셀 속도: 83.33 pixels/second
# 객체 1612의 평균 픽셀 속도: 73.68 pixels/second
# 객체 1613의 평균 픽셀 속도: 206.86 pixels/second
# 객체 1615의 평균 픽셀 속도: 69.88 pixels/second
# 객체 1616의 평균 픽셀 속도: 11.11 pixels/second
# 객체 1617의 평균 픽셀 속도: 107.01 pixels/second
# 객체 1619의 평균 픽셀 속도: 101.08 pixels/second
# 객체 1621의 평균 픽셀 속도: 70.45 pixels/second
# 객체 1622의 평균 픽셀 속도: 46.76 pixels/second
# 객체 1623의 평균 픽셀 속도: 68.64 pixels/second
# 객체 1624의 평균 픽셀 속도: 67.26 pixels/second
# 객체 1627의 평균 픽셀 속도: 91.19 pixels/second
# 객체 1629의 평균 픽셀 속도: 87.99 pixels/second
# 객체 1630의 평균 픽셀 속도: 37.79 pixels/second
# 객체 1631의 평균 픽셀 속도: 92.33 pixels/second
# 객체 1634의 평균 픽셀 속도: 69.38 pixels/second
# 객체 1635의 평균 픽셀 속도: 73.86 pixels/second
# 객체 1636의 평균 픽셀 속도: 76.71 pixels/second
# 객체 1640의 평균 픽셀 속도: 102.02 pixels/second
# 객체 1641의 평균 픽셀 속도: 58.83 pixels/second
# 객체 1642의 평균 픽셀 속도: 86.12 pixels/second
# 객체 1647의 평균 픽셀 속도: 86.74 pixels/second
# 객체 1648의 평균 픽셀 속도: 65.23 pixels/second
# 객체 1651의 평균 픽셀 속도: 111.28 pixels/second
# 객체 1652의 평균 픽셀 속도: 26.48 pixels/second
# 객체 1653의 평균 픽셀 속도: 64.67 pixels/second
# 객체 1655의 평균 픽셀 속도: 0.00 pixels/second
# 객체 1656의 평균 픽셀 속도: 57.72 pixels/second
# 객체 1657의 평균 픽셀 속도: 44.56 pixels/second
# 객체 1658의 평균 픽셀 속도: 54.21 pixels/second
# 객체 1660의 평균 픽셀 속도: 31.89 pixels/second
# 객체 1661의 평균 픽셀 속도: 103.35 pixels/second
# 객체 1662의 평균 픽셀 속도: 8.76 pixels/second
# 객체 1665의 평균 픽셀 속도: 14.83 pixels/second
# 객체 1666의 평균 픽셀 속도: 82.29 pixels/second
# 객체 1668의 평균 픽셀 속도: 108.54 pixels/second
# 객체 1671의 평균 픽셀 속도: 100.85 pixels/second
# 객체 1672의 평균 픽셀 속도: 60.52 pixels/second
# 객체 1674의 평균 픽셀 속도: 37.40 pixels/second
# 객체 1676의 평균 픽셀 속도: 49.94 pixels/second
# 객체 1678의 평균 픽셀 속도: 260.43 pixels/second
# 객체 1679의 평균 픽셀 속도: 93.40 pixels/second
# 객체 1680의 평균 픽셀 속도: 91.43 pixels/second
# 객체 1681의 평균 픽셀 속도: 65.75 pixels/second
# 객체 1682의 평균 픽셀 속도: 167.91 pixels/second
# 객체 1683의 평균 픽셀 속도: 51.26 pixels/second
# 객체 1684의 평균 픽셀 속도: 61.76 pixels/second
# 객체 1687의 평균 픽셀 속도: 66.22 pixels/second
# 객체 1688의 평균 픽셀 속도: 63.77 pixels/second
# 객체 1690의 평균 픽셀 속도: 166.09 pixels/second
# 객체 1691의 평균 픽셀 속도: 31.95 pixels/second
# 객체 1692의 평균 픽셀 속도: 94.44 pixels/second
# 객체 1694의 평균 픽셀 속도: 219.50 pixels/second
# 객체 1695의 평균 픽셀 속도: 68.41 pixels/second
# 객체 1696의 평균 픽셀 속도: 110.74 pixels/second
# 객체 1697의 평균 픽셀 속도: 64.16 pixels/second
# 객체 1698의 평균 픽셀 속도: 104.02 pixels/second
# 객체 1699의 평균 픽셀 속도: 0.00 pixels/second
# 객체 1700의 평균 픽셀 속도: 66.43 pixels/second
# 객체 1702의 평균 픽셀 속도: 100.20 pixels/second
# 객체 1705의 평균 픽셀 속도: 110.02 pixels/second
# 객체 1707의 평균 픽셀 속도: 20.35 pixels/second
# 객체 1708의 평균 픽셀 속도: 78.49 pixels/second
# 객체 1709의 평균 픽셀 속도: 88.85 pixels/second
# 객체 1710의 평균 픽셀 속도: 260.79 pixels/second
# 객체 1711의 평균 픽셀 속도: 83.48 pixels/second
# 객체 1712의 평균 픽셀 속도: 78.22 pixels/second
# 객체 1713의 평균 픽셀 속도: 105.39 pixels/second
# 객체 1714의 평균 픽셀 속도: 70.98 pixels/second
# 객체 1716의 평균 픽셀 속도: 87.44 pixels/second
# 객체 1717의 평균 픽셀 속도: 72.78 pixels/second
# 객체 1718의 평균 픽셀 속도: 68.46 pixels/second
# 객체 1720의 평균 픽셀 속도: 340.90 pixels/second
# 객체 1722의 평균 픽셀 속도: 82.45 pixels/second
# 객체 1724의 평균 픽셀 속도: 83.53 pixels/second
# 객체 1726의 평균 픽셀 속도: 47.66 pixels/second
# 객체 1727의 평균 픽셀 속도: 93.26 pixels/second
# 객체 1732의 평균 픽셀 속도: 0.00 pixels/second
# 객체 1733의 평균 픽셀 속도: 0.00 pixels/second
# 객체 1734의 평균 픽셀 속도: 95.09 pixels/second
# 객체 1736의 평균 픽셀 속도: 50.25 pixels/second
# 객체 1738의 평균 픽셀 속도: 15.31 pixels/second
# 객체 1739의 평균 픽셀 속도: 60.17 pixels/second
# 객체 1743의 평균 픽셀 속도: 76.02 pixels/second
# 객체 1744의 평균 픽셀 속도: 84.64 pixels/second
# 객체 1746의 평균 픽셀 속도: 66.31 pixels/second
# 객체 1747의 평균 픽셀 속도: 0.00 pixels/second
# 객체 1748의 평균 픽셀 속도: 43.17 pixels/second
# 객체 1749의 평균 픽셀 속도: 89.25 pixels/second
# 객체 1750의 평균 픽셀 속도: 93.45 pixels/second
# 객체 1752의 평균 픽셀 속도: 63.68 pixels/second
# 객체 1755의 평균 픽셀 속도: 80.47 pixels/second
# 객체 1757의 평균 픽셀 속도: 0.00 pixels/second
# 객체 1758의 평균 픽셀 속도: 133.45 pixels/second
# 객체 1761의 평균 픽셀 속도: 87.77 pixels/second
# 객체 1762의 평균 픽셀 속도: 94.36 pixels/second
# 객체 1763의 평균 픽셀 속도: 119.93 pixels/second
# 객체 1768의 평균 픽셀 속도: 33.23 pixels/second
# 객체 1769의 평균 픽셀 속도: 59.52 pixels/second
# 객체 1770의 평균 픽셀 속도: 89.02 pixels/second
# 객체 1771의 평균 픽셀 속도: 48.40 pixels/second
# 객체 1776의 평균 픽셀 속도: 71.10 pixels/second
# 객체 1778의 평균 픽셀 속도: 94.84 pixels/second
# 객체 1779의 평균 픽셀 속도: 74.54 pixels/second
# 객체 1780의 평균 픽셀 속도: 80.19 pixels/second
# 객체 1782의 평균 픽셀 속도: 98.52 pixels/second
# 객체 1783의 평균 픽셀 속도: 68.40 pixels/second
# 객체 1786의 평균 픽셀 속도: 0.00 pixels/second
# 객체 1788의 평균 픽셀 속도: 57.73 pixels/second
# 객체 1789의 평균 픽셀 속도: 83.17 pixels/second
# 객체 1790의 평균 픽셀 속도: 87.18 pixels/second
# 객체 1793의 평균 픽셀 속도: 111.56 pixels/second
# 객체 1794의 평균 픽셀 속도: 85.57 pixels/second
# 객체 1795의 평균 픽셀 속도: 17.64 pixels/second
# 객체 1796의 평균 픽셀 속도: 155.78 pixels/second
# 객체 1797의 평균 픽셀 속도: 88.79 pixels/second
# 객체 1800의 평균 픽셀 속도: 0.00 pixels/second
# 객체 1801의 평균 픽셀 속도: 54.39 pixels/second
# 객체 1804의 평균 픽셀 속도: 35.10 pixels/second
# 객체 1808의 평균 픽셀 속도: 84.69 pixels/second
# 객체 1809의 평균 픽셀 속도: 0.00 pixels/second
# 객체 1810의 평균 픽셀 속도: 111.15 pixels/second
# 객체 1811의 평균 픽셀 속도: 88.70 pixels/second
# 객체 1812의 평균 픽셀 속도: 38.75 pixels/second
# 객체 1813의 평균 픽셀 속도: 178.51 pixels/second
# 객체 1814의 평균 픽셀 속도: 83.86 pixels/second
# 객체 1816의 평균 픽셀 속도: 74.44 pixels/second
# 객체 1817의 평균 픽셀 속도: 131.62 pixels/second
# 객체 1819의 평균 픽셀 속도: 87.37 pixels/second
# 객체 1820의 평균 픽셀 속도: 70.25 pixels/second
# 객체 1821의 평균 픽셀 속도: 95.61 pixels/second
# 객체 1822의 평균 픽셀 속도: 73.31 pixels/second
# 객체 1823의 평균 픽셀 속도: 89.57 pixels/second
# 객체 1826의 평균 픽셀 속도: 89.89 pixels/second
# 객체 1827의 평균 픽셀 속도: 123.77 pixels/second
# 객체 1829의 평균 픽셀 속도: 80.42 pixels/second
# 객체 1830의 평균 픽셀 속도: 83.62 pixels/second
# 객체 1831의 평균 픽셀 속도: 61.35 pixels/second
# 객체 1833의 평균 픽셀 속도: 72.38 pixels/second
# 객체 1834의 평균 픽셀 속도: 93.41 pixels/second
# 객체 1839의 평균 픽셀 속도: 66.74 pixels/second
# 객체 1840의 평균 픽셀 속도: 73.85 pixels/second
# 객체 1841의 평균 픽셀 속도: 54.19 pixels/second
# 객체 1842의 평균 픽셀 속도: 115.49 pixels/second
# 객체 1846의 평균 픽셀 속도: 97.18 pixels/second
# 객체 1847의 평균 픽셀 속도: 0.00 pixels/second
# 객체 1849의 평균 픽셀 속도: 78.86 pixels/second
# 객체 1850의 평균 픽셀 속도: 22.83 pixels/second
# 객체 1851의 평균 픽셀 속도: 10.02 pixels/second
# 객체 1852의 평균 픽셀 속도: 0.00 pixels/second
# 객체 1853의 평균 픽셀 속도: 51.12 pixels/second
# 객체 1855의 평균 픽셀 속도: 81.50 pixels/second
# 객체 1857의 평균 픽셀 속도: 15.85 pixels/second
# 객체 1858의 평균 픽셀 속도: 91.67 pixels/second
# 객체 1859의 평균 픽셀 속도: 82.24 pixels/second
# 객체 1861의 평균 픽셀 속도: 65.91 pixels/second
# 객체 1862의 평균 픽셀 속도: 27.62 pixels/second
# 객체 1863의 평균 픽셀 속도: 12.85 pixels/second
# 객체 1865의 평균 픽셀 속도: 65.41 pixels/second
# 객체 1868의 평균 픽셀 속도: 70.42 pixels/second
# 객체 1869의 평균 픽셀 속도: 68.35 pixels/second
# 객체 1873의 평균 픽셀 속도: 20.13 pixels/second
# 객체 1875의 평균 픽셀 속도: 31.43 pixels/second
# 객체 1878의 평균 픽셀 속도: 74.29 pixels/second
# 객체 1880의 평균 픽셀 속도: 87.98 pixels/second
# 객체 1882의 평균 픽셀 속도: 90.36 pixels/second
# 객체 1883의 평균 픽셀 속도: 22.57 pixels/second
# 객체 1886의 평균 픽셀 속도: 74.14 pixels/second
# 객체 1887의 평균 픽셀 속도: 69.35 pixels/second
# 객체 1888의 평균 픽셀 속도: 15.32 pixels/second
# 객체 1889의 평균 픽셀 속도: 79.38 pixels/second
# 객체 1890의 평균 픽셀 속도: 78.38 pixels/second
# 객체 1893의 평균 픽셀 속도: 81.64 pixels/second
# 객체 1895의 평균 픽셀 속도: 92.92 pixels/second
# 객체 1896의 평균 픽셀 속도: 66.42 pixels/second
# 객체 1897의 평균 픽셀 속도: 92.09 pixels/second
# 객체 1899의 평균 픽셀 속도: 64.33 pixels/second
# 객체 1900의 평균 픽셀 속도: 52.43 pixels/second
# 객체 1901의 평균 픽셀 속도: 86.58 pixels/second
# 객체 1903의 평균 픽셀 속도: 71.83 pixels/second
# 객체 1905의 평균 픽셀 속도: 78.46 pixels/second
# 객체 1906의 평균 픽셀 속도: 40.93 pixels/second
# 객체 1908의 평균 픽셀 속도: 70.35 pixels/second
# 객체 1909의 평균 픽셀 속도: 63.99 pixels/second
# 객체 1911의 평균 픽셀 속도: 22.56 pixels/second
# 객체 1912의 평균 픽셀 속도: 45.48 pixels/second
# 객체 1914의 평균 픽셀 속도: 66.96 pixels/second
# 객체 1915의 평균 픽셀 속도: 67.63 pixels/second
# 객체 1916의 평균 픽셀 속도: 93.72 pixels/second
# 객체 1917의 평균 픽셀 속도: 69.93 pixels/second
# 객체 1918의 평균 픽셀 속도: 26.56 pixels/second
# 객체 1920의 평균 픽셀 속도: 69.20 pixels/second
# 객체 1924의 평균 픽셀 속도: 56.88 pixels/second
# 객체 1926의 평균 픽셀 속도: 72.24 pixels/second
# 객체 1931의 평균 픽셀 속도: 33.95 pixels/second
# 객체 1932의 평균 픽셀 속도: 81.70 pixels/second
# 객체 1934의 평균 픽셀 속도: 80.18 pixels/second
# 객체 1937의 평균 픽셀 속도: 78.49 pixels/second
# 객체 1939의 평균 픽셀 속도: 80.86 pixels/second
# 객체 1944의 평균 픽셀 속도: 104.28 pixels/second
# 객체 1945의 평균 픽셀 속도: 74.85 pixels/second
# 객체 1946의 평균 픽셀 속도: 55.65 pixels/second
# 객체 1947의 평균 픽셀 속도: 70.57 pixels/second
# 객체 1950의 평균 픽셀 속도: 74.26 pixels/second
# 객체 1951의 평균 픽셀 속도: 17.96 pixels/second
# 객체 1953의 평균 픽셀 속도: 42.49 pixels/second
# 객체 1954의 평균 픽셀 속도: 20.49 pixels/second
# 객체 1955의 평균 픽셀 속도: 79.40 pixels/second
# 객체 1956의 평균 픽셀 속도: 75.31 pixels/second
# 객체 1957의 평균 픽셀 속도: 70.81 pixels/second
# 객체 1959의 평균 픽셀 속도: 64.95 pixels/second
# 객체 1961의 평균 픽셀 속도: 8.30 pixels/second
# 객체 1962의 평균 픽셀 속도: 81.81 pixels/second
# 객체 1966의 평균 픽셀 속도: 60.17 pixels/second
# 객체 1968의 평균 픽셀 속도: 126.60 pixels/second
# 객체 1969의 평균 픽셀 속도: 21.54 pixels/second
# 객체 1970의 평균 픽셀 속도: 86.54 pixels/second
# 객체 1971의 평균 픽셀 속도: 35.31 pixels/second
# 객체 1972의 평균 픽셀 속도: 6.69 pixels/second
# 객체 1973의 평균 픽셀 속도: 74.94 pixels/second
# 객체 1974의 평균 픽셀 속도: 73.20 pixels/second
# 객체 1975의 평균 픽셀 속도: 89.76 pixels/second
# 객체 1976의 평균 픽셀 속도: 246.69 pixels/second
# 객체 1977의 평균 픽셀 속도: 92.89 pixels/second
# 객체 1978의 평균 픽셀 속도: 0.00 pixels/second
# 객체 1979의 평균 픽셀 속도: 86.21 pixels/second
# 객체 1980의 평균 픽셀 속도: 61.72 pixels/second
# 객체 1983의 평균 픽셀 속도: 74.11 pixels/second
# 객체 1985의 평균 픽셀 속도: 11.01 pixels/second
# 객체 1986의 평균 픽셀 속도: 85.29 pixels/second
# 객체 1990의 평균 픽셀 속도: 41.51 pixels/second
# 객체 1991의 평균 픽셀 속도: 0.00 pixels/second
# 객체 1992의 평균 픽셀 속도: 72.20 pixels/second
# 객체 1993의 평균 픽셀 속도: 58.24 pixels/second
# 객체 1994의 평균 픽셀 속도: 13.70 pixels/second
# 객체 1995의 평균 픽셀 속도: 0.00 pixels/second
# 객체 1996의 평균 픽셀 속도: 292.05 pixels/second
# 객체 1997의 평균 픽셀 속도: 64.07 pixels/second
# 객체 1998의 평균 픽셀 속도: 0.00 pixels/second
# 객체 2000의 평균 픽셀 속도: 45.74 pixels/second
# 객체 2001의 평균 픽셀 속도: 88.36 pixels/second
# 객체 2003의 평균 픽셀 속도: 62.75 pixels/second
# 객체 2005의 평균 픽셀 속도: 0.00 pixels/second
# 객체 2006의 평균 픽셀 속도: 50.92 pixels/second
# 객체 2008의 평균 픽셀 속도: 65.95 pixels/second
# 객체 2010의 평균 픽셀 속도: 39.75 pixels/second
# 객체 2011의 평균 픽셀 속도: 231.43 pixels/second
# 객체 2014의 평균 픽셀 속도: 59.31 pixels/second
# 객체 2015의 평균 픽셀 속도: 27.74 pixels/second
# 객체 2016의 평균 픽셀 속도: 51.86 pixels/second
# 객체 2018의 평균 픽셀 속도: 28.61 pixels/second
# 객체 2021의 평균 픽셀 속도: 88.02 pixels/second
# 객체 2022의 평균 픽셀 속도: 45.52 pixels/second
# 객체 2025의 평균 픽셀 속도: 79.65 pixels/second
# 객체 2028의 평균 픽셀 속도: 19.36 pixels/second
# 객체 2029의 평균 픽셀 속도: 316.30 pixels/second
# 객체 2031의 평균 픽셀 속도: 42.51 pixels/second
# 객체 2033의 평균 픽셀 속도: 155.96 pixels/second
# 객체 2039의 평균 픽셀 속도: 73.53 pixels/second
# 객체 2042의 평균 픽셀 속도: 78.66 pixels/second
# 객체 2044의 평균 픽셀 속도: 339.07 pixels/second
# 객체 2045의 평균 픽셀 속도: 170.34 pixels/second
# 객체 2046의 평균 픽셀 속도: 0.00 pixels/second
# 객체 2047의 평균 픽셀 속도: 70.51 pixels/second
# 객체 2051의 평균 픽셀 속도: 242.10 pixels/second
# 객체 2052의 평균 픽셀 속도: 74.09 pixels/second
# 객체 2053의 평균 픽셀 속도: 90.97 pixels/second
# 객체 2054의 평균 픽셀 속도: 54.01 pixels/second
# 객체 2057의 평균 픽셀 속도: 52.74 pixels/second
# 객체 2058의 평균 픽셀 속도: 0.00 pixels/second
# 객체 2062의 평균 픽셀 속도: 350.51 pixels/second
# 객체 2064의 평균 픽셀 속도: 38.06 pixels/second
# 객체 2065의 평균 픽셀 속도: 106.50 pixels/second
# 객체 2066의 평균 픽셀 속도: 76.25 pixels/second
# 객체 2067의 평균 픽셀 속도: 0.00 pixels/second
# 객체 2069의 평균 픽셀 속도: 138.91 pixels/second
# 객체 2070의 평균 픽셀 속도: 388.75 pixels/second
# 객체 2073의 평균 픽셀 속도: 71.35 pixels/second
# 객체 2074의 평균 픽셀 속도: 80.60 pixels/second
# 객체 2075의 평균 픽셀 속도: 8.98 pixels/second
# 객체 2076의 평균 픽셀 속도: 50.89 pixels/second
# 객체 2077의 평균 픽셀 속도: 87.85 pixels/second
# 객체 2078의 평균 픽셀 속도: 59.40 pixels/second
# 객체 2079의 평균 픽셀 속도: 93.69 pixels/second
# 객체 2081의 평균 픽셀 속도: 66.85 pixels/second
# 객체 2082의 평균 픽셀 속도: 21.30 pixels/second
# 객체 2083의 평균 픽셀 속도: 0.00 pixels/second
# 객체 2087의 평균 픽셀 속도: 80.30 pixels/second
# 객체 2088의 평균 픽셀 속도: 69.88 pixels/second
# 객체 2089의 평균 픽셀 속도: 326.73 pixels/second
# 객체 2090의 평균 픽셀 속도: 162.10 pixels/second
# 객체 2091의 평균 픽셀 속도: 76.29 pixels/second
# 객체 2092의 평균 픽셀 속도: 76.76 pixels/second
# 객체 2093의 평균 픽셀 속도: 63.02 pixels/second
# 객체 2094의 평균 픽셀 속도: 0.00 pixels/second
# 객체 2095의 평균 픽셀 속도: 111.43 pixels/second
# 객체 2097의 평균 픽셀 속도: 81.78 pixels/second
# 객체 2098의 평균 픽셀 속도: 71.38 pixels/second
# 객체 2099의 평균 픽셀 속도: 78.12 pixels/second
# 객체 2100의 평균 픽셀 속도: 165.46 pixels/second
# 객체 2101의 평균 픽셀 속도: 75.99 pixels/second
# 객체 2102의 평균 픽셀 속도: 98.27 pixels/second
# ...
# 객체 2554의 평균 픽셀 속도: 69.50 pixels/second
# 객체 2556의 평균 픽셀 속도: 29.93 pixels/second
# 객체 2557의 평균 픽셀 속도: 98.51 pixels/second
# 객체 2558의 평균 픽셀 속도: 89.69 pixels/second
# 객체 2560의 평균 픽셀 속도: 145.40 pixels/second
# 객체 2564의 평균 픽셀 속도: 108.10 pixels/second
# 객체 2565의 평균 픽셀 속도: 75.22 pixels/second
# 객체 2566의 평균 픽셀 속도: 107.24 pixels/second
# 객체 2568의 평균 픽셀 속도: 54.13 pixels/second
# 객체 2569의 평균 픽셀 속도: 95.29 pixels/second
# 객체 2570의 평균 픽셀 속도: 125.40 pixels/second
# 객체 2571의 평균 픽셀 속도: 195.13 pixels/second
# 객체 2572의 평균 픽셀 속도: 90.24 pixels/second
# 객체 2573의 평균 픽셀 속도: 82.85 pixels/second
# 객체 2574의 평균 픽셀 속도: 153.10 pixels/second
# 객체 2575의 평균 픽셀 속도: 81.66 pixels/second
# 객체 2576의 평균 픽셀 속도: 80.39 pixels/second
# 객체 2577의 평균 픽셀 속도: 80.62 pixels/second
# 객체 2578의 평균 픽셀 속도: 135.04 pixels/second
# 객체 2579의 평균 픽셀 속도: 90.29 pixels/second
# 객체 2581의 평균 픽셀 속도: 215.22 pixels/second
# 객체 2582의 평균 픽셀 속도: 74.87 pixels/second
# 객체 2584의 평균 픽셀 속도: 87.37 pixels/second
# 객체 2588의 평균 픽셀 속도: 54.80 pixels/second
# 객체 2589의 평균 픽셀 속도: 0.00 pixels/second
# 객체 2590의 평균 픽셀 속도: 76.10 pixels/second
# 객체 2592의 평균 픽셀 속도: 152.52 pixels/second
# 객체 2594의 평균 픽셀 속도: 136.51 pixels/second
# 객체 2595의 평균 픽셀 속도: 71.65 pixels/second
# 객체 2596의 평균 픽셀 속도: 48.72 pixels/second
# 객체 2597의 평균 픽셀 속도: 67.04 pixels/second
# 객체 2600의 평균 픽셀 속도: 91.93 pixels/second
# 객체 2601의 평균 픽셀 속도: 102.67 pixels/second
# 객체 2603의 평균 픽셀 속도: 110.17 pixels/second
# 객체 2604의 평균 픽셀 속도: 97.76 pixels/second
# 객체 2606의 평균 픽셀 속도: 26.93 pixels/second
# 객체 2608의 평균 픽셀 속도: 36.37 pixels/second
# 객체 2610의 평균 픽셀 속도: 76.09 pixels/second
# 객체 2612의 평균 픽셀 속도: 26.05 pixels/second
# 객체 2613의 평균 픽셀 속도: 106.02 pixels/second
# 객체 2615의 평균 픽셀 속도: 89.64 pixels/second
# 객체 2617의 평균 픽셀 속도: 87.33 pixels/second
# 객체 2618의 평균 픽셀 속도: 25.86 pixels/second
# 객체 2619의 평균 픽셀 속도: 26.04 pixels/second
# 객체 2620의 평균 픽셀 속도: 26.03 pixels/second
# 객체 2621의 평균 픽셀 속도: 3.04 pixels/second
# 객체 2623의 평균 픽셀 속도: 0.00 pixels/second
# 객체 2624의 평균 픽셀 속도: 200.35 pixels/second
# 객체 2625의 평균 픽셀 속도: 34.68 pixels/second
# 객체 2628의 평균 픽셀 속도: 89.15 pixels/second
# 객체 2629의 평균 픽셀 속도: 73.60 pixels/second
# 객체 2630의 평균 픽셀 속도: 81.40 pixels/second
# 객체 2631의 평균 픽셀 속도: 55.02 pixels/second
# 객체 2632의 평균 픽셀 속도: 10.08 pixels/second
# 객체 2633의 평균 픽셀 속도: 63.70 pixels/second
# 객체 2634의 평균 픽셀 속도: 76.85 pixels/second
# 객체 2635의 평균 픽셀 속도: 81.62 pixels/second
# 객체 2636의 평균 픽셀 속도: 71.87 pixels/second
# 객체 2638의 평균 픽셀 속도: 103.28 pixels/second
# 객체 2639의 평균 픽셀 속도: 74.45 pixels/second
# 객체 2640의 평균 픽셀 속도: 0.00 pixels/second
# 객체 2641의 평균 픽셀 속도: 97.08 pixels/second
# 객체 2642의 평균 픽셀 속도: 61.60 pixels/second
# 객체 2643의 평균 픽셀 속도: 59.10 pixels/second
# 객체 2644의 평균 픽셀 속도: 56.02 pixels/second
# 객체 2648의 평균 픽셀 속도: 75.31 pixels/second
# 객체 2650의 평균 픽셀 속도: 97.05 pixels/second
# 객체 2652의 평균 픽셀 속도: 59.88 pixels/second
# 객체 2653의 평균 픽셀 속도: 67.93 pixels/second
# 객체 2654의 평균 픽셀 속도: 101.58 pixels/second
# 객체 2656의 평균 픽셀 속도: 159.36 pixels/second
# 객체 2658의 평균 픽셀 속도: 59.11 pixels/second
# 객체 2660의 평균 픽셀 속도: 76.99 pixels/second
# 객체 2661의 평균 픽셀 속도: 226.61 pixels/second
# 객체 2663의 평균 픽셀 속도: 131.98 pixels/second
# 객체 2665의 평균 픽셀 속도: 117.64 pixels/second
# 객체 2666의 평균 픽셀 속도: 24.65 pixels/second
# 객체 2667의 평균 픽셀 속도: 28.38 pixels/second
# 객체 2671의 평균 픽셀 속도: 94.99 pixels/second
# 객체 2673의 평균 픽셀 속도: 60.17 pixels/second
# 객체 2675의 평균 픽셀 속도: 29.45 pixels/second
# 객체 2676의 평균 픽셀 속도: 0.00 pixels/second
# 객체 2677의 평균 픽셀 속도: 30.81 pixels/second
# 객체 2679의 평균 픽셀 속도: 65.12 pixels/second
# 객체 2680의 평균 픽셀 속도: 61.43 pixels/second
# 객체 2681의 평균 픽셀 속도: 67.84 pixels/second
# 객체 2683의 평균 픽셀 속도: 96.54 pixels/second
# 객체 2685의 평균 픽셀 속도: 0.00 pixels/second
# 객체 2686의 평균 픽셀 속도: 65.72 pixels/second
# 객체 2689의 평균 픽셀 속도: 0.00 pixels/second
# 객체 2690의 평균 픽셀 속도: 69.95 pixels/second
# 객체 2691의 평균 픽셀 속도: 32.33 pixels/second
# 객체 2695의 평균 픽셀 속도: 55.10 pixels/second
# 객체 2698의 평균 픽셀 속도: 58.35 pixels/second
# 객체 2699의 평균 픽셀 속도: 34.01 pixels/second
# 객체 2702의 평균 픽셀 속도: 102.92 pixels/second
# 객체 2703의 평균 픽셀 속도: 64.51 pixels/second
# 객체 2704의 평균 픽셀 속도: 35.05 pixels/second
# 객체 2705의 평균 픽셀 속도: 42.24 pixels/second
# 객체 2706의 평균 픽셀 속도: 28.07 pixels/second
# 객체 2707의 평균 픽셀 속도: 63.65 pixels/second
# 객체 2708의 평균 픽셀 속도: 262.59 pixels/second
# 객체 2710의 평균 픽셀 속도: 13.84 pixels/second
# 객체 2711의 평균 픽셀 속도: 17.48 pixels/second
# 객체 2712의 평균 픽셀 속도: 79.34 pixels/second
# 객체 2715의 평균 픽셀 속도: 95.37 pixels/second
# 객체 2716의 평균 픽셀 속도: 64.46 pixels/second
# 객체 2718의 평균 픽셀 속도: 12.82 pixels/second
# 객체 2719의 평균 픽셀 속도: 55.56 pixels/second
# 객체 2720의 평균 픽셀 속도: 75.12 pixels/second
# 객체 2721의 평균 픽셀 속도: 10.76 pixels/second
# 객체 2722의 평균 픽셀 속도: 17.57 pixels/second
# 객체 2725의 평균 픽셀 속도: 46.73 pixels/second
# 객체 2727의 평균 픽셀 속도: 56.02 pixels/second
# 객체 2728의 평균 픽셀 속도: 60.56 pixels/second
# 객체 2729의 평균 픽셀 속도: 82.30 pixels/second
# 객체 2731의 평균 픽셀 속도: 74.34 pixels/second
# 객체 2732의 평균 픽셀 속도: 46.65 pixels/second
# 객체 2733의 평균 픽셀 속도: 156.18 pixels/second
# 객체 2734의 평균 픽셀 속도: 85.38 pixels/second
# 객체 2738의 평균 픽셀 속도: 86.93 pixels/second
# 객체 2739의 평균 픽셀 속도: 7.51 pixels/second
# 객체 2740의 평균 픽셀 속도: 84.85 pixels/second
# 객체 2741의 평균 픽셀 속도: 61.77 pixels/second
# 객체 2744의 평균 픽셀 속도: 87.25 pixels/second
# 객체 2745의 평균 픽셀 속도: 55.90 pixels/second
# 객체 2746의 평균 픽셀 속도: 27.90 pixels/second
# 객체 2747의 평균 픽셀 속도: 112.55 pixels/second
# 객체 2750의 평균 픽셀 속도: 68.90 pixels/second
# 객체 2754의 평균 픽셀 속도: 320.90 pixels/second
# 객체 2755의 평균 픽셀 속도: 58.74 pixels/second
# 객체 2756의 평균 픽셀 속도: 91.75 pixels/second
# 객체 2759의 평균 픽셀 속도: 43.35 pixels/second
# 객체 2760의 평균 픽셀 속도: 237.16 pixels/second
# 객체 2763의 평균 픽셀 속도: 73.66 pixels/second
# 객체 2765의 평균 픽셀 속도: 81.33 pixels/second
# 객체 2766의 평균 픽셀 속도: 81.84 pixels/second
# 객체 2768의 평균 픽셀 속도: 203.60 pixels/second
# 객체 2769의 평균 픽셀 속도: 76.75 pixels/second
# 객체 2771의 평균 픽셀 속도: 120.77 pixels/second
# 객체 2772의 평균 픽셀 속도: 14.41 pixels/second
# 객체 2774의 평균 픽셀 속도: 5.33 pixels/second
# 객체 2777의 평균 픽셀 속도: 48.23 pixels/second
# 객체 2778의 평균 픽셀 속도: 29.68 pixels/second
# 객체 2779의 평균 픽셀 속도: 34.00 pixels/second
# 객체 2780의 평균 픽셀 속도: 51.08 pixels/second
# 객체 2782의 평균 픽셀 속도: 346.98 pixels/second
# 객체 2784의 평균 픽셀 속도: 42.45 pixels/second
# 객체 2785의 평균 픽셀 속도: 61.32 pixels/second
# 객체 2789의 평균 픽셀 속도: 13.36 pixels/second
# 객체 2790의 평균 픽셀 속도: 6.99 pixels/second
# 객체 2791의 평균 픽셀 속도: 44.84 pixels/second
# 객체 2792의 평균 픽셀 속도: 220.65 pixels/second
# 객체 2794의 평균 픽셀 속도: 81.23 pixels/second
# 객체 2796의 평균 픽셀 속도: 23.01 pixels/second
# 객체 2798의 평균 픽셀 속도: 14.43 pixels/second
# 객체 2800의 평균 픽셀 속도: 92.54 pixels/second
# 객체 2801의 평균 픽셀 속도: 78.05 pixels/second
# 객체 2802의 평균 픽셀 속도: 85.59 pixels/second
# 객체 2803의 평균 픽셀 속도: 314.99 pixels/second
# 객체 2804의 평균 픽셀 속도: 86.48 pixels/second
# 객체 2806의 평균 픽셀 속도: 54.06 pixels/second
# 객체 2807의 평균 픽셀 속도: 53.77 pixels/second
# 객체 2808의 평균 픽셀 속도: 36.98 pixels/second
# 객체 2809의 평균 픽셀 속도: 36.39 pixels/second
# 객체 2811의 평균 픽셀 속도: 37.73 pixels/second
# 객체 2812의 평균 픽셀 속도: 10.82 pixels/second
# 객체 2813의 평균 픽셀 속도: 80.23 pixels/second
# 객체 2816의 평균 픽셀 속도: 53.06 pixels/second
# 객체 2817의 평균 픽셀 속도: 59.28 pixels/second
# 객체 2819의 평균 픽셀 속도: 119.85 pixels/second
# 객체 2820의 평균 픽셀 속도: 338.50 pixels/second
# 객체 2822의 평균 픽셀 속도: 89.03 pixels/second
# 객체 2823의 평균 픽셀 속도: 75.05 pixels/second
# 객체 2824의 평균 픽셀 속도: 61.66 pixels/second
# 객체 2826의 평균 픽셀 속도: 71.57 pixels/second
# 객체 2828의 평균 픽셀 속도: 31.23 pixels/second
# 객체 2832의 평균 픽셀 속도: 22.06 pixels/second
# 객체 2833의 평균 픽셀 속도: 13.52 pixels/second
# 객체 2834의 평균 픽셀 속도: 13.41 pixels/second
# 객체 2837의 평균 픽셀 속도: 87.40 pixels/second
# 객체 2838의 평균 픽셀 속도: 85.17 pixels/second
# 객체 2839의 평균 픽셀 속도: 79.30 pixels/second
# 객체 2840의 평균 픽셀 속도: 39.33 pixels/second
# 객체 2841의 평균 픽셀 속도: 74.57 pixels/second
# 객체 2843의 평균 픽셀 속도: 360.19 pixels/second
# 객체 2844의 평균 픽셀 속도: 100.72 pixels/second
# 객체 2848의 평균 픽셀 속도: 34.10 pixels/second
# 객체 2849의 평균 픽셀 속도: 36.79 pixels/second
# 객체 2850의 평균 픽셀 속도: 89.27 pixels/second
# 객체 2851의 평균 픽셀 속도: 37.36 pixels/second
# 객체 2852의 평균 픽셀 속도: 61.81 pixels/second
# 객체 2853의 평균 픽셀 속도: 13.99 pixels/second
# 객체 2854의 평균 픽셀 속도: 88.60 pixels/second
# 객체 2856의 평균 픽셀 속도: 70.31 pixels/second
# 객체 2857의 평균 픽셀 속도: 31.74 pixels/second
# 객체 2858의 평균 픽셀 속도: 13.30 pixels/second
# 객체 2859의 평균 픽셀 속도: 30.58 pixels/second
# 객체 2860의 평균 픽셀 속도: 393.65 pixels/second
# 객체 2861의 평균 픽셀 속도: 210.80 pixels/second
# 객체 2862의 평균 픽셀 속도: 10.78 pixels/second
# 객체 2864의 평균 픽셀 속도: 304.41 pixels/second
# 객체 2865의 평균 픽셀 속도: 607.83 pixels/second
# 객체 2867의 평균 픽셀 속도: 116.25 pixels/second
# 객체 2869의 평균 픽셀 속도: 0.00 pixels/second
# 객체 2871의 평균 픽셀 속도: 37.04 pixels/second
# 객체 2872의 평균 픽셀 속도: 81.45 pixels/second
# 객체 2873의 평균 픽셀 속도: 10.25 pixels/second
# 객체 2875의 평균 픽셀 속도: 88.53 pixels/second
# 객체 2878의 평균 픽셀 속도: 70.61 pixels/second
# 객체 2883의 평균 픽셀 속도: 0.00 pixels/second
# 객체 2884의 평균 픽셀 속도: 321.97 pixels/second
# 객체 2885의 평균 픽셀 속도: 87.41 pixels/second
# 객체 2886의 평균 픽셀 속도: 635.99 pixels/second
# 객체 2888의 평균 픽셀 속도: 14.34 pixels/second
# 객체 2891의 평균 픽셀 속도: 47.05 pixels/second
# 객체 2892의 평균 픽셀 속도: 89.10 pixels/second
# 객체 2893의 평균 픽셀 속도: 335.07 pixels/second
# 객체 2894의 평균 픽셀 속도: 19.36 pixels/second
# 객체 2895의 평균 픽셀 속도: 691.45 pixels/second
# 객체 2898의 평균 픽셀 속도: 68.17 pixels/second
# 객체 2901의 평균 픽셀 속도: 256.59 pixels/second
# 객체 2904의 평균 픽셀 속도: 76.63 pixels/second
# 객체 2907의 평균 픽셀 속도: 672.79 pixels/second
# 객체 2910의 평균 픽셀 속도: 13.27 pixels/second
# 객체 2911의 평균 픽셀 속도: 437.05 pixels/second
# 객체 2914의 평균 픽셀 속도: 14.86 pixels/second
# 객체 2915의 평균 픽셀 속도: 4.63 pixels/second
# 객체 2916의 평균 픽셀 속도: 301.38 pixels/second
# 객체 2917의 평균 픽셀 속도: 50.61 pixels/second
# 객체 2918의 평균 픽셀 속도: 602.25 pixels/second
# 객체 2919의 평균 픽셀 속도: 112.59 pixels/second
# 객체 2921의 평균 픽셀 속도: 62.14 pixels/second
# 객체 2922의 평균 픽셀 속도: 19.36 pixels/second
# 객체 2924의 평균 픽셀 속도: 487.32 pixels/second
# 객체 2927의 평균 픽셀 속도: 104.19 pixels/second
# 객체 2929의 평균 픽셀 속도: 24.82 pixels/second
# 객체 2933의 평균 픽셀 속도: 57.57 pixels/second
# 객체 2936의 평균 픽셀 속도: 0.00 pixels/second
# 객체 2937의 평균 픽셀 속도: 45.03 pixels/second
# 객체 2939의 평균 픽셀 속도: 63.34 pixels/second
# 객체 2940의 평균 픽셀 속도: 45.87 pixels/second
# 객체 2942의 평균 픽셀 속도: 5.82 pixels/second
# 객체 2944의 평균 픽셀 속도: 45.05 pixels/second
# 객체 2946의 평균 픽셀 속도: 75.19 pixels/second
# 객체 2947의 평균 픽셀 속도: 294.82 pixels/second
# 객체 2949의 평균 픽셀 속도: 591.71 pixels/second
# 객체 2951의 평균 픽셀 속도: 359.46 pixels/second
# 객체 2952의 평균 픽셀 속도: 55.63 pixels/second
# 객체 2953의 평균 픽셀 속도: 620.63 pixels/second
# 객체 2954의 평균 픽셀 속도: 67.25 pixels/second
# 객체 2955의 평균 픽셀 속도: 60.23 pixels/second
# 객체 2956의 평균 픽셀 속도: 87.46 pixels/second
# 객체 2957의 평균 픽셀 속도: 73.42 pixels/second
# 객체 2959의 평균 픽셀 속도: 303.73 pixels/second
# 객체 2960의 평균 픽셀 속도: 46.22 pixels/second
# 객체 2961의 평균 픽셀 속도: 5.59 pixels/second
# 객체 2962의 평균 픽셀 속도: 582.15 pixels/second
# 객체 2963의 평균 픽셀 속도: 6.66 pixels/second
# 객체 2964의 평균 픽셀 속도: 12.10 pixels/second
# 객체 2968의 평균 픽셀 속도: 79.51 pixels/second
# 객체 2972의 평균 픽셀 속도: 316.85 pixels/second
# 객체 2973의 평균 픽셀 속도: 585.09 pixels/second
# 객체 2974의 평균 픽셀 속도: 53.32 pixels/second
# 객체 2976의 평균 픽셀 속도: 8.04 pixels/second
# 객체 2977의 평균 픽셀 속도: 29.46 pixels/second
# 객체 2978의 평균 픽셀 속도: 75.71 pixels/second
# 객체 2979의 평균 픽셀 속도: 60.73 pixels/second
# 객체 2981의 평균 픽셀 속도: 231.33 pixels/second
# 객체 2982의 평균 픽셀 속도: 52.90 pixels/second
# 객체 2983의 평균 픽셀 속도: 79.08 pixels/second
# 객체 2985의 평균 픽셀 속도: 5.95 pixels/second
# 객체 2986의 평균 픽셀 속도: 94.69 pixels/second
# 객체 2987의 평균 픽셀 속도: 9.82 pixels/second
# 객체 2988의 평균 픽셀 속도: 46.52 pixels/second
# 객체 2990의 평균 픽셀 속도: 69.82 pixels/second
# 객체 2992의 평균 픽셀 속도: 12.03 pixels/second
# 객체 2994의 평균 픽셀 속도: 72.05 pixels/second
# 객체 2995의 평균 픽셀 속도: 63.26 pixels/second
# 객체 2997의 평균 픽셀 속도: 79.26 pixels/second
# 객체 2998의 평균 픽셀 속도: 52.00 pixels/second
# 객체 3000의 평균 픽셀 속도: 14.57 pixels/second
# 객체 3001의 평균 픽셀 속도: 63.20 pixels/second
# 객체 3004의 평균 픽셀 속도: 100.87 pixels/second
# 객체 3005의 평균 픽셀 속도: 113.66 pixels/second
# 객체 3006의 평균 픽셀 속도: 83.22 pixels/second
# 객체 3008의 평균 픽셀 속도: 41.22 pixels/second
# 객체 3009의 평균 픽셀 속도: 70.48 pixels/second
# 객체 3011의 평균 픽셀 속도: 12.53 pixels/second
# 객체 3013의 평균 픽셀 속도: 44.24 pixels/second
# 객체 3014의 평균 픽셀 속도: 93.97 pixels/second
# 객체 3015의 평균 픽셀 속도: 12.98 pixels/second
# 객체 3016의 평균 픽셀 속도: 33.62 pixels/second
# 객체 3019의 평균 픽셀 속도: 84.82 pixels/second
# 객체 3020의 평균 픽셀 속도: 80.63 pixels/second
# 객체 3021의 평균 픽셀 속도: 67.26 pixels/second
# 객체 3022의 평균 픽셀 속도: 64.71 pixels/second
# 객체 3023의 평균 픽셀 속도: 71.88 pixels/second
# 객체 3024의 평균 픽셀 속도: 13.44 pixels/second
# 객체 3027의 평균 픽셀 속도: 59.34 pixels/second
# 객체 3028의 평균 픽셀 속도: 75.79 pixels/second
# 객체 3029의 평균 픽셀 속도: 68.99 pixels/second
# 객체 3031의 평균 픽셀 속도: 80.36 pixels/second
# 객체 3032의 평균 픽셀 속도: 55.21 pixels/second
# 객체 3033의 평균 픽셀 속도: 82.42 pixels/second
# 객체 3034의 평균 픽셀 속도: 78.38 pixels/second
# 객체 3037의 평균 픽셀 속도: 78.99 pixels/second
# 객체 3040의 평균 픽셀 속도: 84.80 pixels/second
# 객체 3042의 평균 픽셀 속도: 49.42 pixels/second
# 객체 3043의 평균 픽셀 속도: 37.65 pixels/second
# 객체 3045의 평균 픽셀 속도: 54.37 pixels/second
# 객체 3048의 평균 픽셀 속도: 0.00 pixels/second
# 객체 3052의 평균 픽셀 속도: 84.42 pixels/second
# 객체 3055의 평균 픽셀 속도: 9.41 pixels/second
# 객체 3056의 평균 픽셀 속도: 81.78 pixels/second
# 객체 3057의 평균 픽셀 속도: 318.36 pixels/second
# 객체 3062의 평균 픽셀 속도: 97.78 pixels/second
# 객체 3063의 평균 픽셀 속도: 97.16 pixels/second
# 객체 3064의 평균 픽셀 속도: 34.71 pixels/second
# 객체 3066의 평균 픽셀 속도: 102.90 pixels/second
# 객체 3067의 평균 픽셀 속도: 64.38 pixels/second
# 객체 3069의 평균 픽셀 속도: 17.54 pixels/second
# 객체 3071의 평균 픽셀 속도: 41.69 pixels/second
# 객체 3073의 평균 픽셀 속도: 99.14 pixels/second
# 객체 3080의 평균 픽셀 속도: 69.84 pixels/second
# 객체 3082의 평균 픽셀 속도: 138.85 pixels/second
# 객체 3083의 평균 픽셀 속도: 29.28 pixels/second
# 객체 3085의 평균 픽셀 속도: 90.82 pixels/second
# 객체 3086의 평균 픽셀 속도: 87.00 pixels/second
# 객체 3087의 평균 픽셀 속도: 0.00 pixels/second
# 객체 3089의 평균 픽셀 속도: 10.62 pixels/second
# 객체 3092의 평균 픽셀 속도: 193.02 pixels/second
# 객체 3095의 평균 픽셀 속도: 251.70 pixels/second
# 객체 3100의 평균 픽셀 속도: 86.39 pixels/second
# 객체 3101의 평균 픽셀 속도: 91.50 pixels/second
# 객체 3102의 평균 픽셀 속도: 48.84 pixels/second
# 객체 3103의 평균 픽셀 속도: 153.91 pixels/second
# 객체 3106의 평균 픽셀 속도: 79.14 pixels/second
# 객체 3108의 평균 픽셀 속도: 14.50 pixels/second
# 객체 3109의 평균 픽셀 속도: 78.42 pixels/second
# 객체 3113의 평균 픽셀 속도: 78.64 pixels/second
# 객체 3114의 평균 픽셀 속도: 64.63 pixels/second
# 객체 3116의 평균 픽셀 속도: 76.40 pixels/second
# 객체 3119의 평균 픽셀 속도: 103.09 pixels/second
# 객체 3120의 평균 픽셀 속도: 94.90 pixels/second
# 객체 3121의 평균 픽셀 속도: 138.98 pixels/second
# 객체 3122의 평균 픽셀 속도: 62.78 pixels/second
# 객체 3124의 평균 픽셀 속도: 90.64 pixels/second
# 객체 3127의 평균 픽셀 속도: 16.36 pixels/second
# 객체 3128의 평균 픽셀 속도: 86.71 pixels/second
# 객체 3129의 평균 픽셀 속도: 72.00 pixels/second
# 객체 3131의 평균 픽셀 속도: 70.18 pixels/second
# 객체 3132의 평균 픽셀 속도: 88.96 pixels/second
# 객체 3134의 평균 픽셀 속도: 49.78 pixels/second
# 객체 3135의 평균 픽셀 속도: 211.54 pixels/second
# 객체 3136의 평균 픽셀 속도: 74.34 pixels/second
# 객체 3138의 평균 픽셀 속도: 21.18 pixels/second
# 객체 3140의 평균 픽셀 속도: 101.24 pixels/second
# 객체 3141의 평균 픽셀 속도: 89.44 pixels/second
# 객체 3148의 평균 픽셀 속도: 18.94 pixels/second
# 객체 3150의 평균 픽셀 속도: 88.67 pixels/second
# 객체 3153의 평균 픽셀 속도: 19.27 pixels/second
# 객체 3154의 평균 픽셀 속도: 25.79 pixels/second
# 객체 3155의 평균 픽셀 속도: 100.12 pixels/second
# 객체 3156의 평균 픽셀 속도: 9.85 pixels/second
# 객체 3157의 평균 픽셀 속도: 51.49 pixels/second
# 객체 3158의 평균 픽셀 속도: 85.96 pixels/second
# 객체 3159의 평균 픽셀 속도: 16.00 pixels/second
# 객체 3160의 평균 픽셀 속도: 73.45 pixels/second
# 객체 3161의 평균 픽셀 속도: 15.16 pixels/second
# 객체 3162의 평균 픽셀 속도: 61.10 pixels/second
# 객체 3163의 평균 픽셀 속도: 78.85 pixels/second
# 객체 3164의 평균 픽셀 속도: 86.37 pixels/second
# 객체 3168의 평균 픽셀 속도: 82.47 pixels/second
# 객체 3169의 평균 픽셀 속도: 24.91 pixels/second
# 객체 3170의 평균 픽셀 속도: 42.99 pixels/second
# 객체 3172의 평균 픽셀 속도: 50.12 pixels/second
# 객체 3173의 평균 픽셀 속도: 47.97 pixels/second
# 객체 3174의 평균 픽셀 속도: 80.34 pixels/second
# 객체 3176의 평균 픽셀 속도: 90.36 pixels/second
# 객체 3179의 평균 픽셀 속도: 53.10 pixels/second
# 객체 3181의 평균 픽셀 속도: 76.61 pixels/second
# 객체 3182의 평균 픽셀 속도: 79.37 pixels/second
# 객체 3183의 평균 픽셀 속도: 0.00 pixels/second
# 객체 3185의 평균 픽셀 속도: 72.21 pixels/second
# 객체 3186의 평균 픽셀 속도: 89.57 pixels/second
# 객체 3187의 평균 픽셀 속도: 15.49 pixels/second
# 객체 3188의 평균 픽셀 속도: 7.48 pixels/second
# 객체 3189의 평균 픽셀 속도: 22.45 pixels/second
# 객체 3191의 평균 픽셀 속도: 62.12 pixels/second
# 객체 3192의 평균 픽셀 속도: 5.59 pixels/second
# 객체 3193의 평균 픽셀 속도: 79.19 pixels/second
# 객체 3194의 평균 픽셀 속도: 85.08 pixels/second
# 객체 3196의 평균 픽셀 속도: 14.10 pixels/second
# 객체 3198의 평균 픽셀 속도: 179.85 pixels/second
# 객체 3200의 평균 픽셀 속도: 63.33 pixels/second
# 객체 3203의 평균 픽셀 속도: 90.91 pixels/second
# 객체 3204의 평균 픽셀 속도: 4.80 pixels/second
# 객체 3206의 평균 픽셀 속도: 75.01 pixels/second
# 객체 3207의 평균 픽셀 속도: 104.91 pixels/second
# 객체 3209의 평균 픽셀 속도: 108.02 pixels/second
# 객체 3211의 평균 픽셀 속도: 86.86 pixels/second
# 객체 3213의 평균 픽셀 속도: 0.00 pixels/second
# 객체 3214의 평균 픽셀 속도: 89.95 pixels/second
# 객체 3215의 평균 픽셀 속도: 99.48 pixels/second
# 객체 3216의 평균 픽셀 속도: 124.17 pixels/second
# 객체 3217의 평균 픽셀 속도: 38.85 pixels/second
# 객체 3218의 평균 픽셀 속도: 63.97 pixels/second

# %%
import math


class GeoreferencingService:
    def __init__(self, camera_fov, video_width, video_height):
        """
        Georeferencing 서비스 초기화.

        Args:
            camera_fov (float): 카메라의 수평 시야각 (degrees)
            video_width (int): 비디오 해상도 가로 크기 (pixels)
            video_height (int): 비디오 해상도 세로 크기 (pixels)
        """
        if not (0 < camera_fov < 180):
            raise ValueError("카메라 수평 시야각은 0~180도 사이여야 합니다.")
        if video_width <= 0 or video_height <= 0:
            raise ValueError("비디오 해상도가 유효하지 않습니다.")

        self.camera_fov = camera_fov
        self.video_width = video_width
        self.video_height = video_height
        self.center_x = video_width / 2
        self.center_y = video_height / 2
        self.diagonal_pixels = math.sqrt(video_width**2 + video_height**2)

    def normalize_coordinates(self, bbox):
        """
        객체의 중심점을 정규화된 좌표로 변환 (-1 to 1 범위).

        Args:
            bbox (list): [x1, y1, x2, y2] 바운딩 박스 좌표.

        Returns:
            dict: 정규화된 x, y 좌표.
        """
        x1, y1, x2, y2 = bbox
        center_x = (x1 + x2) / 2
        center_y = (y1 + y2) / 2

        return {
            "x": (center_x - self.center_x) / self.center_x,
            "y": (center_y - self.center_y) / self.center_y,
        }

    def calculate_object_location(self, bbox, drone_position, heading, altitude):
        """
        객체의 지리적 위치 계산.

        Args:
            bbox (list): [x1, y1, x2, y2] 바운딩 박스 좌표.
            drone_position (tuple): 드론의 GPS 위치 (latitude, longitude).
            heading (float): 드론의 진행 방향 (degrees).
            altitude (float): 드론의 고도 (meters).

        Returns:
            tuple: 객체의 GPS 위치 (latitude, longitude).
        """
        normalized = self.normalize_coordinates(bbox)

        # 영상 중심으로부터의 상대적 거리 계산
        pixel_distance = math.sqrt(
            (normalized["x"] * self.center_x) ** 2
            + (normalized["y"] * self.center_y) ** 2
        )

        # 실제 거리 계산
        distance_ratio = pixel_distance / self.diagonal_pixels
        fov_radians = math.radians(self.camera_fov)
        ground_distance = altitude * math.tan(fov_radians / 2) * distance_ratio

        # 방위각 계산 (y축 반전)
        bearing = math.degrees(math.atan2(normalized["x"], -normalized["y"]))
        bearing = (bearing + heading) % 360

        # 최종 위치 계산
        return self.calculate_destination(drone_position, ground_distance, bearing)

    def calculate_destination(self, start_coords, distance, bearing):
        """
        시작 좌표에서 주어진 거리와 방위각으로 이동한 결과 좌표 계산.

        Args:
            start_coords (tuple): 시작 GPS 좌표 (latitude, longitude).
            distance (float): 이동 거리 (meters).
            bearing (float): 방위각 (degrees).

        Returns:
            tuple: 이동한 결과 GPS 좌표 (latitude, longitude).
        """
        lat1 = math.radians(start_coords[0])
        lon1 = math.radians(start_coords[1])
        bearing_rad = math.radians(bearing)
        earth_radius = 6371000  # 지구 반지름 (meters)

        # 새로운 좌표 계산
        lat2 = math.asin(
            math.sin(lat1) * math.cos(distance / earth_radius)
            + math.cos(lat1) * math.sin(distance / earth_radius) * math.cos(bearing_rad)
        )
        lon2 = lon1 + math.atan2(
            math.sin(bearing_rad) * math.sin(distance / earth_radius) * math.cos(lat1),
            math.cos(distance / earth_radius) - math.sin(lat1) * math.sin(lat2),
        )

        return math.degrees(lat2), math.degrees(lon2)

# %%
# DJI Mini 2의 FOV
DJI_MINI2_FOV = 83  # 수평 시야각 (degrees)

for i, segment in enumerate(segments):
    print(f"Processing video segment {i + 1}/{len(segments)}...")

    # Tracking 데이터 로드
    with open(tracking_paths[i], "r") as f:
        tracking_data = json.load(f)

    # 비디오 메타데이터에서 이미지 크기 가져오기
    video_metadata = tracking_data["video"]
    georef_service = GeoreferencingService(
        camera_fov=DJI_MINI2_FOV,
        video_width=video_metadata["width"],
        video_height=video_metadata["height"],
    )

    # 프레임 데이터 생성
    frames = create_frame_drone_mapping(segment, tracking_data)

    # 픽셀 속도 계산
    object_pixel_speeds = calculate_pixel_speed(frames)

    # 픽셀 크기 변환 비율 계산
    fov_radians = math.radians(DJI_MINI2_FOV)
    altitude = frames[0]["drone_state"]["altitude"]  # 첫 프레임의 고도 사용
    ground_width = 2 * altitude * math.tan(fov_radians / 2)  # 지면 상의 폭 (meters)
    meters_per_pixel = (
        ground_width / video_metadata["width"]
    )  # 픽셀당 실제 거리 (meters)

    # 첫 두 프레임 출력
    for j in range(2):
        print(f"\n비디오 {i + 1}, 첫 {j + 1} 프레임 정보:")
        print(f"프레임 인덱스: {frames[j]['frame_index']}")
        print(f"타임스탬프: {frames[j]['timestamp']:.2f}초")
        print(f"드론 상태:")
        print(f"  위도: {frames[j]['drone_state']['latitude']}")
        print(f"  경도: {frames[j]['drone_state']['longitude']}")
        print(f"  고도: {frames[j]['drone_state']['altitude']:.1f}m")
        print(f"  방향: {frames[j]['drone_state']['heading']}°")
        print(f"객체 수: {len(frames[j]['objects'])}")

    # 교차점 데이터 생성
    intersections = analyze_trajectories_in_frame_window(frames)
    print(f"\n발견된 교차점 수: {len(intersections)}")
    if intersections:
        print("\n첫 5개 교차점:")
        for k, intersection in enumerate(
            sorted(intersections, key=lambda x: -x["time_difference"])[:5]
        ):
            print(f"\n교차점 {k + 1}:")
            print(intersection)

    # 계층적 JSON 구조 생성
    video_data = {
        "start_time": segment["time(millisecond)"].iloc[0] / 1000,
        "end_time": segment["time(millisecond)"].iloc[-1] / 1000,
        "start_location": {
            "latitude": segment["latitude"].iloc[0],
            "longitude": segment["longitude"].iloc[0],
        },
        "end_location": {
            "latitude": segment["latitude"].iloc[-1],
            "longitude": segment["longitude"].iloc[-1],
        },
        "frames": [],
        "tracking": [],
        "intersections": [],
    }

    # 프레임 추가
    for frame in frames:
        frame_data = {
            "frame_index": frame["frame_index"],
            "timestamp": frame["timestamp"],
            "drone_state": frame["drone_state"],
            "detections": [],
        }

        # Detection 처리
        for obj in frame["objects"]:
            # 바운딩 박스 중심의 GPS 계산
            gps_coords = georef_service.calculate_object_location(
                bbox=obj["bbox"],
                drone_position=(
                    frame["drone_state"]["latitude"],
                    frame["drone_state"]["longitude"],
                ),
                heading=frame["drone_state"]["heading"],
                altitude=frame["drone_state"]["altitude"],
            )

            # 월드 속도 계산
            pixel_speed = (
                object_pixel_speeds[obj["tid"]]["speeds"][0]
                if obj["tid"] in object_pixel_speeds
                and object_pixel_speeds[obj["tid"]]["speeds"]
                else 0
            )
            world_speed = pixel_speed * meters_per_pixel

            # Detection 데이터에 월드 속도와 GPS 좌표 추가
            frame_data["detections"].append(
                {
                    "class_id": obj["cid"],
                    "track_id": obj["tid"],
                    "bbox": obj["bbox"],
                    "confidence": obj["conf"],
                    "world_speed": world_speed,
                    "gps_coordinates": {
                        "latitude": gps_coords[0],
                        "longitude": gps_coords[1],
                    },
                }
            )

        video_data["frames"].append(frame_data)

    # 트래킹 데이터 추가
    trajectory_segments = get_trajectory_segments(frames, 0, len(frames))
    for segment in trajectory_segments:
        video_data["tracking"].append(
            {
                "track_id": segment.track_id,
                "frame_start": segment.frame1,
                "frame_end": segment.frame2,
                "start_point": segment.p1,
                "end_point": segment.p2,
                "timestamp_start": segment.t1,
                "timestamp_end": segment.t2,
            }
        )

    # 교차점 추가
    for intersection in intersections:
        intersection_gps_coords = georef_service.calculate_object_location(
            bbox=[
                intersection["intersection_point"][0],
                intersection["intersection_point"][1],
                intersection["intersection_point"][0],
                intersection["intersection_point"][1],
            ],
            drone_position=(
                frame["drone_state"]["latitude"],
                frame["drone_state"]["longitude"],
            ),
            heading=frame["drone_state"]["heading"],
            altitude=frame["drone_state"]["altitude"],
        )
        video_data["intersections"].append(
            {
                "frame_index": intersection["frame_index"],
                "timestamp": intersection["timestamp"],
                "track_id1": intersection["track_id1"],
                "track_id2": intersection["track_id2"],
                "intersection_point": intersection["intersection_point"],
                "gps_coordinates": {
                    "latitude": intersection_gps_coords[0],
                    "longitude": intersection_gps_coords[1],
                },
                "time_difference": intersection["time_difference"],
            }
        )

    # JSON 파일로 저장
    output_file = f"segment_{i + 1}.json"
    with open(output_file, "w") as f:
        json.dump(video_data, f, indent=2)

    print(f"비디오 세그먼트 {i + 1} JSON 파일로 저장되었습니다: {output_file}")
# Out:
# Processing video segment 1/2...
# 프레임 매핑: 100%|██████████| 9223/9223 [00:01<00:00, 7701.63it/s]
# 비디오 1, 첫 1 프레임 정보:
# 프레임 인덱스: 0
# 타임스탬프: 591.60초
# 드론 상태:
#   위도: 37.4510599991108
#   경도: 126.656443306919
#   고도: 40.0m
#   방향: 289.1°
# 객체 수: 68
#
# 비디오 1, 첫 2 프레임 정보:
# 프레임 인덱스: 1
# 타임스탬프: 591.63초
# 드론 상태:
#   위도: 37.4510599991108
#   경도: 126.656443306919
#   고도: 40.0m
#   방향: 289.1°
# 객체 수: 68
# 궤적 분석: 100%|██████████| 30/30 [00:34<00:00,  1.16s/it]
# 발견된 교차점 수: 865
#
# 첫 5개 교차점:
#
# 교차점 1:
# {'frame_index': 2100, 'timestamp': np.float64(661.6700000000001), 'track_id1': 1033, 'track_id2': 1203, 'intersection_point': (3798.8519711862505, 1779.6623222335807), 'time_difference': np.float64(9.94326666666666)}
#
# 교차점 2:
# {'frame_index': 4500, 'timestamp': np.float64(741.75), 'track_id1': 58, 'track_id2': 2065, 'intersection_point': (646.1100661718681, 460.1118117490573), 'time_difference': np.float64(9.909899999999993)}
#
# 교차점 3:
# {'frame_index': 6001, 'timestamp': np.float64(791.8333666666667), 'track_id1': 2154, 'track_id2': 2400, 'intersection_point': (2773.4315012389684, 1174.6255821522943), 'time_difference': np.float64(9.876533333333327)}
#
# 교차점 4:
# {'frame_index': 604, 'timestamp': np.float64(611.7534666666667), 'track_id1': 247, 'track_id2': 312, 'intersection_point': (3770.6862051170056, 846.053899180088), 'time_difference': np.float64(9.476133333333337)}
#
# 교차점 5:
# {'frame_index': 3610, 'timestamp': np.float64(712.0536666666667), 'track_id1': 1342, 'track_id2': 1355, 'intersection_point': (3526.7607399009376, 876.5929813569677), 'time_difference': np.float64(9.275933333333342)}
# 비디오 세그먼트 1 JSON 파일로 저장되었습니다: segment_1.json
# Processing video segment 2/2...
# 프레임 매핑: 100%|██████████| 7498/7498 [00:01<00:00, 7142.36it/s]
# 비디오 2, 첫 1 프레임 정보:
# 프레임 인덱스: 0
# 타임스탬프: 967.40초
# 드론 상태:
#   위도: 37.4491993632329
#   경도: 126.656012908395
#   고도: 40.3m
#   방향: 268.1°
# 객체 수: 9
#
# 비디오 2, 첫 2 프레임 정보:
# 프레임 인덱스: 1
# 타임스탬프: 967.43초
# 드론 상태:
#   위도: 37.4491993632329
#   경도: 126.656012908395
#   고도: 40.3m
#   방향: 268.1°
# 객체 수: 9
# 궤적 분석: 100%|██████████| 24/24 [00:06<00:00,  3.67it/s]
# 발견된 교차점 수: 73
#
# 첫 5개 교차점:
#
# 교차점 1:
# {'frame_index': 2406, 'timestamp': np.float64(1047.6802), 'track_id1': 207, 'track_id2': 288, 'intersection_point': (1016.7924876709712, 1565.404410301429), 'time_difference': np.float64(8.07473333333337)}
#
# 교차점 2:
# {'frame_index': 5434, 'timestamp': np.float64(1148.7144666666666), 'track_id1': 592, 'track_id2': 665, 'intersection_point': (2488.7267467163224, 1947.6698973228017), 'time_difference': np.float64(7.941266666666706)}
#
# 교차점 3:
# {'frame_index': 3914, 'timestamp': np.float64(1097.9971333333333), 'track_id1': 444, 'track_id2': 467, 'intersection_point': (1338.4561928278342, 1410.0165066409972), 'time_difference': np.float64(7.540866666666716)}
#
# 교차점 4:
# {'frame_index': 6633, 'timestamp': np.float64(1188.7211), 'track_id1': 758, 'track_id2': 784, 'intersection_point': (2049.473588185539, 1194.1669040341553), 'time_difference': np.float64(7.507499999999936)}
#
# 교차점 5:
# {'frame_index': 4506, 'timestamp': np.float64(1117.7502), 'track_id1': 499, 'track_id2': 565, 'intersection_point': (2953.987013298582, 1922.0956267436293), 'time_difference': np.float64(7.440766666666605)}
# 비디오 세그먼트 2 JSON 파일로 저장되었습니다: segment_2.json
